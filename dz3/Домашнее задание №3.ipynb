# %%
'''
1) Выберите любой открытый датасет и скачайте открытый датасет, соответствующий вашим интересам или области обучения.
    --использовал датасет из прошлого домашнего задания(ДЗ №2) car_price_dataset.csv
2) Создайте новую базу данных в системе управления базами данных (например, SQLite, PostgreSQL).
    --создал БД car_price_db в PostgreSQL
3) Создайте таблицу (или несколько таблиц) в базе данных с различными типами данных (INTEGER, TEXT, DATE), которые требуются для вашего датасета. Импортируйте данные из датасета в созданные таблицы.
    --при создания таблицы импортировал текущий датасет в таблицу PostgreSQL
'''
# Out:
# '\n1) Выберите любой открытый датасет и скачайте открытый датасет, соответствующий вашим интересам или области обучения.\n    --использовал датасет из прошлого домашнего задания(ДЗ №2) car_price_dataset.csv\n2) Создайте новую базу данных в системе управления базами данных (например, SQLite, PostgreSQL).\n    --создал БД car_price_db в PostgreSQL\n3) Создайте таблицу (или несколько таблиц) в базе данных с различными типами данных (INTEGER, TEXT, DATE), которые требуются для вашего датасета. Импортируйте данные из датасета в созданные таблицы.\n    --при создания таблицы импортировал текущий датасет в таблицу PostgreSQL\n'

# %%
import psycopg2
import logging

logging.basicConfig(filename='log.log', level=logging.INFO, format="%(asctime)s %(levelname)s %(module)s %(message)s") 
logger = logging.getLogger(__name__)

try:
    conn = psycopg2.connect(dbname="car_price_db", host="192.168.1.196", user="dwhadmin", password="123", port="5432")
except Exception as e:
    logger.exception(f"Ошибка подключения к БД: {e}")

cursor = conn.cursor()
print('Подключение выполнено')
cursor.execute('SELECT * FROM carprice')
carprice_analyst = cursor.fetchall()
for carprice in carprice_analyst:
    print(carprice)

conn.close()
# Out:
# Подключение выполнено
# ('Kia', 'Rio', 2020, 4.2, 'Diesel', 'Manual', 289944, 3, 5, 8501)
# ('Audi', 'Q5', 2023, 2.0, 'Electric', 'Manual', 160971, 2, 1, 11780)
# ('Volkswagen', 'Golf', 2003, 2.6, 'Hybrid', 'Semi-Automatic', 286618, 3, 3, 2867)
# ('BMW', '5 Series', 2013, 1.3, 'Hybrid', 'Automatic', 296824, 2, 3, 5863)
# ('Volkswagen', 'Golf', 2009, 4.5, 'Hybrid', 'Manual', 42795, 4, 3, 11444)
# ('Hyundai', 'Elantra', 2004, 2.3, 'Hybrid', 'Semi-Automatic', 188996, 2, 1, 4820)
# ('Hyundai', 'Elantra', 2017, 2.9, 'Electric', 'Automatic', 38133, 5, 2, 14837)
# ('Mercedes', 'GLA', 2021, 1.5, 'Petrol', 'Manual', 34640, 2, 1, 11207)
# ('Chevrolet', 'Equinox', 2018, 1.8, 'Hybrid', 'Automatic', 21261, 2, 1, 13374)
# ('Toyota', 'RAV4', 2003, 2.0, 'Electric', 'Manual', 136662, 5, 4, 6266)
# ('Audi', 'A3', 2022, 3.3, 'Electric', 'Manual', 79350, 5, 3, 14413)
# ('BMW', '3 Series', 2017, 2.3, 'Electric', 'Semi-Automatic', 142701, 5, 3, 10645)
# ('Kia', 'Sportage', 2000, 1.4, 'Electric', 'Manual', 167050, 5, 4, 4159)
# ('Audi', 'Q5', 2023, 3.6, 'Electric', 'Manual', 238306, 5, 2, 11833)
# ('Ford', 'Focus', 2011, 2.3, 'Diesel', 'Automatic', 255372, 5, 5, 6092)
# ('Audi', 'A4', 2009, 2.4, 'Diesel', 'Manual', 263797, 2, 5, 3924)
# ('Audi', 'A3', 2009, 1.2, 'Electric', 'Automatic', 111448, 5, 1, 9271)
# ('BMW', '3 Series', 2011, 2.9, 'Electric', 'Semi-Automatic', 281020, 3, 5, 6679)
# ('Chevrolet', 'Impala', 2017, 1.8, 'Diesel', 'Semi-Automatic', 22175, 2, 2, 10556)
# ('Toyota', 'Camry', 2008, 1.3, 'Petrol', 'Automatic', 188097, 2, 2, 5538)
# ('Volkswagen', 'Passat', 2005, 3.2, 'Electric', 'Semi-Automatic', 155550, 5, 4, 7689)
# ('Ford', 'Fiesta', 2002, 4.0, 'Hybrid', 'Semi-Automatic', 272351, 3, 3, 4252)
# ('Hyundai', 'Tucson', 2018, 2.8, 'Petrol', 'Manual', 160349, 4, 3, 9093)
# ('Kia', 'Sportage', 2017, 2.7, 'Hybrid', 'Automatic', 242456, 2, 5, 9550)
# ('Honda', 'CR-V', 2022, 3.4, 'Diesel', 'Automatic', 248894, 5, 2, 10622)
# ('Mercedes', 'GLA', 2007, 2.3, 'Electric', 'Manual', 76458, 3, 5, 8970)
# ('Hyundai', 'Sonata', 2018, 2.0, 'Hybrid', 'Automatic', 121567, 4, 4, 11568)
# ('Volkswagen', 'Tiguan', 2020, 1.7, 'Petrol', 'Automatic', 195565, 2, 5, 9388)
# ('Volkswagen', 'Passat', 2007, 3.8, 'Electric', 'Manual', 272609, 4, 5, 6547)
# ('Kia', 'Optima', 2017, 4.6, 'Diesel', 'Manual', 197307, 3, 1, 9853)
# ('Audi', 'Q5', 2016, 2.5, 'Electric', 'Semi-Automatic', 121855, 5, 5, 10962)
# ('Volkswagen', 'Passat', 2011, 4.7, 'Petrol', 'Automatic', 203960, 5, 3, 9520)
# ('Audi', 'A3', 2022, 3.8, 'Electric', 'Semi-Automatic', 275109, 2, 5, 10997)
# ('Ford', 'Explorer', 2013, 5.0, 'Electric', 'Automatic', 188195, 5, 3, 12736)
# ('BMW', '5 Series', 2001, 2.3, 'Diesel', 'Semi-Automatic', 66264, 2, 1, 5374)
# ('Hyundai', 'Elantra', 2012, 2.6, 'Hybrid', 'Manual', 11213, 5, 5, 11075)
# ('BMW', '3 Series', 2018, 2.3, 'Electric', 'Semi-Automatic', 99243, 3, 3, 11815)
# ('Ford', 'Fiesta', 2013, 3.5, 'Hybrid', 'Semi-Automatic', 167809, 2, 3, 9143)
# ('Honda', 'Civic', 2007, 1.4, 'Petrol', 'Manual', 279031, 5, 3, 2019)
# ('Chevrolet', 'Equinox', 2013, 2.8, 'Petrol', 'Manual', 63430, 4, 5, 9531)
# ('Mercedes', 'E-Class', 2023, 3.9, 'Hybrid', 'Semi-Automatic', 58107, 3, 2, 14737)
# ('BMW', 'X5', 2002, 4.5, 'Diesel', 'Manual', 86763, 2, 5, 7464)
# ('Toyota', 'Corolla', 2002, 3.9, 'Diesel', 'Semi-Automatic', 281616, 2, 3, 2967)
# ('Chevrolet', 'Malibu', 2013, 1.4, 'Diesel', 'Automatic', 131485, 3, 5, 8270)
# ('Mercedes', 'C-Class', 2020, 3.7, 'Petrol', 'Semi-Automatic', 148489, 3, 5, 10830)
# ('Kia', 'Optima', 2020, 4.7, 'Petrol', 'Manual', 132200, 2, 1, 12156)
# ('Volkswagen', 'Golf', 2001, 4.1, 'Petrol', 'Automatic', 32602, 3, 4, 9347)
# ('Audi', 'A3', 2013, 3.2, 'Electric', 'Manual', 253611, 2, 4, 8127)
# ('Mercedes', 'E-Class', 2004, 3.0, 'Hybrid', 'Manual', 232438, 3, 3, 4651)
# ('Toyota', 'RAV4', 2004, 1.3, 'Electric', 'Automatic', 79437, 4, 4, 8511)
# ('Toyota', 'Camry', 2002, 1.5, 'Petrol', 'Automatic', 23115, 2, 1, 7237)
# ('Toyota', 'RAV4', 2021, 2.1, 'Petrol', 'Manual', 289967, 4, 3, 6700)
# ('Ford', 'Explorer', 2023, 4.1, 'Electric', 'Automatic', 67072, 4, 3, 17258)
# ('Hyundai', 'Tucson', 2002, 4.9, 'Hybrid', 'Automatic', 33244, 2, 2, 11435)
# ('Audi', 'A4', 2015, 2.1, 'Diesel', 'Automatic', 54522, 3, 5, 11109)
# ('Audi', 'A3', 2002, 4.0, 'Diesel', 'Manual', 16302, 5, 2, 8373)
# ('Honda', 'CR-V', 2014, 4.0, 'Petrol', 'Manual', 287926, 5, 2, 6541)
# ('Audi', 'A3', 2001, 1.8, 'Petrol', 'Automatic', 43196, 5, 2, 6836)
# ('Chevrolet', 'Impala', 2018, 3.7, 'Petrol', 'Semi-Automatic', 157181, 5, 2, 10056)
# ('Toyota', 'RAV4', 2013, 4.3, 'Electric', 'Semi-Automatic', 225452, 4, 5, 9790)
# ('Audi', 'Q5', 2014, 2.4, 'Petrol', 'Semi-Automatic', 230787, 3, 1, 6084)
# ('Chevrolet', 'Equinox', 2009, 2.8, 'Electric', 'Manual', 79962, 3, 2, 10000)
# ('Volkswagen', 'Golf', 2014, 3.9, 'Electric', 'Automatic', 95537, 4, 2, 13789)
# ('Mercedes', 'GLA', 2021, 4.3, 'Diesel', 'Manual', 229873, 4, 2, 10102)
# ('Chevrolet', 'Impala', 2011, 4.0, 'Hybrid', 'Automatic', 136926, 5, 1, 11161)
# ('Hyundai', 'Sonata', 2010, 1.6, 'Petrol', 'Automatic', 112946, 2, 5, 7941)
# ('Toyota', 'RAV4', 2008, 3.5, 'Electric', 'Semi-Automatic', 296747, 3, 1, 6065)
# ('Volkswagen', 'Golf', 2021, 4.0, 'Diesel', 'Automatic', 32991, 5, 3, 15240)
# ('Toyota', 'Camry', 2007, 2.2, 'Diesel', 'Manual', 87444, 4, 4, 6651)
# ('BMW', '5 Series', 2009, 1.4, 'Petrol', 'Manual', 232049, 3, 2, 3559)
# ('BMW', '5 Series', 2011, 3.0, 'Petrol', 'Automatic', 260151, 5, 1, 6696)
# ('Ford', 'Fiesta', 2014, 3.9, 'Electric', 'Automatic', 267949, 3, 2, 10341)
# ('Ford', 'Fiesta', 2014, 3.2, 'Petrol', 'Automatic', 253316, 3, 5, 7933)
# ('Mercedes', 'E-Class', 2007, 3.2, 'Diesel', 'Semi-Automatic', 203452, 2, 4, 5330)
# ('Chevrolet', 'Malibu', 2008, 2.5, 'Petrol', 'Semi-Automatic', 215987, 5, 3, 4680)
# ('Honda', 'CR-V', 2009, 2.8, 'Diesel', 'Manual', 201403, 3, 5, 5571)
# ('BMW', '3 Series', 2021, 3.9, 'Petrol', 'Manual', 263073, 4, 3, 9038)
# ('Toyota', 'RAV4', 2006, 1.0, 'Diesel', 'Automatic', 107474, 4, 5, 6250)
# ('Toyota', 'Camry', 2002, 2.6, 'Petrol', 'Automatic', 118041, 3, 4, 6439)
# ('Audi', 'A4', 2020, 4.3, 'Diesel', 'Semi-Automatic', 186962, 3, 5, 10660)
# ('Mercedes', 'GLA', 2023, 1.3, 'Electric', 'Semi-Automatic', 78961, 5, 2, 12720)
# ('Toyota', 'RAV4', 2019, 2.0, 'Petrol', 'Automatic', 232074, 3, 5, 8658)
# ('Ford', 'Explorer', 2001, 2.3, 'Electric', 'Manual', 38542, 5, 2, 7929)
# ('BMW', 'X5', 2010, 2.9, 'Diesel', 'Automatic', 295058, 5, 1, 5598)
# ('Ford', 'Explorer', 2008, 3.9, 'Electric', 'Semi-Automatic', 225838, 5, 3, 7883)
# ('Mercedes', 'C-Class', 2022, 3.1, 'Petrol', 'Automatic', 282199, 2, 2, 9656)
# ('Mercedes', 'C-Class', 2004, 4.0, 'Diesel', 'Manual', 191859, 3, 5, 5462)
# ('Volkswagen', 'Golf', 2019, 3.9, 'Petrol', 'Manual', 230974, 5, 3, 9080)
# ('Audi', 'Q5', 2023, 1.9, 'Diesel', 'Manual', 52679, 5, 3, 11846)
# ('Toyota', 'Camry', 2014, 1.0, 'Petrol', 'Manual', 177766, 3, 2, 5744)
# ('Honda', 'Civic', 2007, 1.6, 'Electric', 'Manual', 158154, 3, 4, 6636)
# ('Toyota', 'Camry', 2023, 1.5, 'Diesel', 'Manual', 117049, 2, 5, 10159)
# ('Toyota', 'Camry', 2000, 1.8, 'Electric', 'Automatic', 271405, 4, 4, 3971)
# ('Hyundai', 'Sonata', 2010, 2.6, 'Hybrid', 'Semi-Automatic', 260006, 3, 3, 5499)
# ('Kia', 'Optima', 2009, 1.6, 'Electric', 'Automatic', 222076, 5, 4, 7458)
# ('Audi', 'Q5', 2015, 3.7, 'Diesel', 'Semi-Automatic', 57196, 3, 1, 11156)
# ('Hyundai', 'Elantra', 2003, 4.4, 'Hybrid', 'Semi-Automatic', 169451, 2, 2, 7010)
# ('Chevrolet', 'Malibu', 2004, 4.9, 'Diesel', 'Manual', 242712, 5, 4, 5345)
# ('Kia', 'Optima', 2002, 1.7, 'Diesel', 'Manual', 79442, 4, 2, 4811)
# ('Volkswagen', 'Tiguan', 2008, 4.3, 'Diesel', 'Semi-Automatic', 261478, 4, 5, 5570)
# ('Mercedes', 'C-Class', 2014, 2.9, 'Petrol', 'Manual', 217980, 4, 4, 6840)
# ('Volkswagen', 'Passat', 2010, 4.1, 'Electric', 'Automatic', 71288, 5, 2, 13274)
# ('BMW', '5 Series', 2016, 4.5, 'Diesel', 'Manual', 91092, 2, 1, 11578)
# ('Chevrolet', 'Malibu', 2015, 2.9, 'Diesel', 'Automatic', 144743, 2, 3, 10105)
# ('Chevrolet', 'Malibu', 2022, 3.0, 'Diesel', 'Manual', 5679, 2, 4, 13586)
# ('BMW', '3 Series', 2011, 3.3, 'Hybrid', 'Manual', 14586, 4, 1, 11408)
# ('Kia', 'Sportage', 2001, 3.6, 'Hybrid', 'Semi-Automatic', 202216, 3, 3, 4955)
# ('Ford', 'Focus', 2008, 2.4, 'Petrol', 'Manual', 126868, 5, 3, 6362)
# ('Ford', 'Fiesta', 2021, 4.3, 'Hybrid', 'Semi-Automatic', 201170, 3, 5, 11676)
# ('BMW', '3 Series', 2020, 2.1, 'Diesel', 'Semi-Automatic', 191301, 3, 1, 8373)
# ('Kia', 'Sportage', 2002, 4.4, 'Petrol', 'Semi-Automatic', 169424, 3, 3, 5711)
# ('Chevrolet', 'Malibu', 2001, 4.8, 'Electric', 'Semi-Automatic', 145630, 2, 1, 8287)
# ('Chevrolet', 'Equinox', 2020, 2.9, 'Petrol', 'Automatic', 22360, 2, 5, 14052)
# ('Mercedes', 'E-Class', 2018, 3.4, 'Diesel', 'Manual', 53596, 5, 1, 11828)
# ('Honda', 'Accord', 2000, 3.6, 'Electric', 'Semi-Automatic', 45737, 5, 1, 8785)
# ('Toyota', 'Camry', 2007, 2.7, 'Petrol', 'Automatic', 157889, 4, 4, 7242)
# ('Kia', 'Sportage', 2014, 2.6, 'Hybrid', 'Manual', 98700, 3, 4, 9926)
# ('Toyota', 'RAV4', 2005, 3.1, 'Petrol', 'Manual', 107724, 2, 5, 6545)
# ('Volkswagen', 'Golf', 2007, 3.2, 'Diesel', 'Automatic', 60103, 2, 1, 9697)
# ('Volkswagen', 'Tiguan', 2006, 4.5, 'Electric', 'Manual', 41161, 2, 2, 11576)
# ('Toyota', 'RAV4', 2000, 4.6, 'Hybrid', 'Semi-Automatic', 41814, 2, 2, 8863)
# ('Ford', 'Explorer', 2006, 2.8, 'Hybrid', 'Manual', 99921, 4, 2, 7701)
# ('BMW', '3 Series', 2020, 4.7, 'Electric', 'Semi-Automatic', 210767, 3, 3, 12584)
# ('Chevrolet', 'Equinox', 2013, 1.9, 'Hybrid', 'Automatic', 121816, 4, 4, 9963)
# ('Hyundai', 'Tucson', 2007, 3.9, 'Electric', 'Automatic', 213643, 4, 5, 9327)
# ('Volkswagen', 'Passat', 2008, 3.5, 'Electric', 'Manual', 88381, 3, 1, 10232)
# ('Chevrolet', 'Impala', 2017, 2.3, 'Petrol', 'Automatic', 183619, 5, 1, 9327)
# ('Toyota', 'Corolla', 2010, 3.2, 'Diesel', 'Automatic', 132454, 4, 4, 9150)
# ('Audi', 'Q5', 2013, 3.5, 'Hybrid', 'Semi-Automatic', 263411, 4, 1, 7231)
# ('Ford', 'Fiesta', 2017, 2.2, 'Hybrid', 'Manual', 277363, 2, 4, 6852)
# ('Ford', 'Focus', 2004, 1.2, 'Electric', 'Manual', 93645, 3, 3, 6627)
# ('BMW', '5 Series', 2007, 4.9, 'Petrol', 'Manual', 120491, 2, 1, 8690)
# ('Honda', 'Civic', 2000, 3.9, 'Hybrid', 'Manual', 56020, 2, 4, 7879)
# ('Mercedes', 'GLA', 2013, 1.9, 'Petrol', 'Manual', 205005, 2, 2, 5799)
# ('Honda', 'Civic', 2015, 2.6, 'Electric', 'Semi-Automatic', 66777, 5, 1, 11864)
# ('Volkswagen', 'Passat', 2003, 2.0, 'Electric', 'Manual', 287728, 3, 3, 3245)
# ('Hyundai', 'Sonata', 2007, 3.6, 'Electric', 'Automatic', 102907, 3, 3, 11241)
# ('Mercedes', 'C-Class', 2007, 2.7, 'Hybrid', 'Manual', 147310, 5, 2, 6953)
# ('Mercedes', 'GLA', 2011, 4.0, 'Diesel', 'Manual', 140263, 4, 5, 8594)
# ('Volkswagen', 'Golf', 2000, 4.0, 'Hybrid', 'Manual', 237232, 4, 5, 4355)
# ('Hyundai', 'Elantra', 2007, 1.5, 'Diesel', 'Manual', 30793, 5, 1, 7084)
# ('BMW', '3 Series', 2019, 1.9, 'Electric', 'Automatic', 6745, 2, 1, 15065)
# ('BMW', 'X5', 2017, 3.9, 'Hybrid', 'Semi-Automatic', 2020, 3, 2, 14059)
# ('Ford', 'Fiesta', 2007, 4.5, 'Electric', 'Manual', 53088, 3, 2, 11638)
# ('Audi', 'A4', 2004, 4.8, 'Hybrid', 'Semi-Automatic', 141850, 3, 2, 8263)
# ('Mercedes', 'C-Class', 2015, 4.1, 'Petrol', 'Automatic', 197249, 3, 1, 10255)
# ('Toyota', 'Corolla', 2014, 4.1, 'Petrol', 'Automatic', 17100, 5, 5, 13558)
# ('BMW', 'X5', 2007, 4.2, 'Petrol', 'Automatic', 129851, 3, 4, 9302)
# ('BMW', '5 Series', 2009, 3.0, 'Electric', 'Manual', 17260, 5, 5, 11454)
# ('Toyota', 'Corolla', 2016, 2.8, 'Hybrid', 'Semi-Automatic', 203314, 3, 3, 8633)
# ('Audi', 'A4', 2010, 2.0, 'Hybrid', 'Manual', 228204, 3, 4, 5535)
# ('Toyota', 'Camry', 2022, 4.5, 'Electric', 'Semi-Automatic', 162696, 4, 2, 13946)
# ('Honda', 'Accord', 2003, 3.8, 'Electric', 'Semi-Automatic', 236022, 3, 2, 6079)
# ('Mercedes', 'C-Class', 2023, 4.6, 'Electric', 'Semi-Automatic', 274137, 2, 3, 12117)
# ('Volkswagen', 'Golf', 2020, 3.8, 'Diesel', 'Automatic', 257521, 3, 3, 10249)
# ('Toyota', 'Corolla', 2013, 4.0, 'Diesel', 'Manual', 213052, 4, 4, 7738)
# ('BMW', '3 Series', 2017, 1.9, 'Petrol', 'Semi-Automatic', 117943, 2, 4, 8741)
# ('Volkswagen', 'Tiguan', 2008, 4.5, 'Electric', 'Semi-Automatic', 178837, 3, 4, 9423)
# ('Audi', 'A4', 2013, 3.9, 'Electric', 'Manual', 21399, 5, 3, 13472)
# ('Chevrolet', 'Equinox', 2017, 3.1, 'Electric', 'Manual', 189399, 5, 4, 10512)
# ('Volkswagen', 'Passat', 2015, 4.7, 'Diesel', 'Manual', 220366, 5, 1, 8892)
# ('Chevrolet', 'Impala', 2009, 2.0, 'Petrol', 'Manual', 184695, 5, 1, 5106)
# ('Toyota', 'Camry', 2019, 4.7, 'Petrol', 'Manual', 114139, 5, 4, 12217)
# ('Honda', 'Accord', 2019, 2.2, 'Diesel', 'Manual', 127801, 5, 5, 9443)
# ('Kia', 'Optima', 2010, 3.9, 'Petrol', 'Automatic', 26930, 3, 3, 11961)
# ('Ford', 'Focus', 2001, 3.2, 'Petrol', 'Manual', 42064, 2, 3, 6758)
# ('Hyundai', 'Sonata', 2018, 3.5, 'Electric', 'Manual', 233614, 4, 2, 10327)
# ('BMW', 'X5', 2017, 2.5, 'Electric', 'Manual', 256380, 2, 1, 8572)
# ('Mercedes', 'E-Class', 2014, 3.8, 'Electric', 'Semi-Automatic', 5877, 5, 5, 13982)
# ('Hyundai', 'Tucson', 2005, 3.6, 'Petrol', 'Semi-Automatic', 157073, 2, 1, 6058)
# ('Mercedes', 'GLA', 2013, 1.4, 'Electric', 'Semi-Automatic', 231290, 3, 3, 6774)
# ('Audi', 'Q5', 2015, 2.9, 'Hybrid', 'Semi-Automatic', 252824, 3, 1, 7443)
# ('Kia', 'Sportage', 2000, 2.8, 'Electric', 'Semi-Automatic', 264697, 2, 5, 3606)
# ('Mercedes', 'C-Class', 2011, 2.3, 'Electric', 'Semi-Automatic', 885, 3, 2, 11682)
# ('Audi', 'Q5', 2022, 3.8, 'Diesel', 'Automatic', 186035, 4, 3, 12279)
# ('Ford', 'Fiesta', 2005, 1.0, 'Hybrid', 'Semi-Automatic', 68819, 2, 3, 6223)
# ('Mercedes', 'C-Class', 2007, 3.9, 'Petrol', 'Semi-Automatic', 97350, 3, 3, 8153)
# ('Volkswagen', 'Passat', 2016, 3.5, 'Diesel', 'Manual', 271497, 5, 4, 6970)
# ('Kia', 'Optima', 2010, 3.8, 'Petrol', 'Automatic', 51040, 5, 2, 11379)
# ('Volkswagen', 'Golf', 2012, 4.2, 'Electric', 'Semi-Automatic', 7544, 2, 5, 13749)
# ('Honda', 'CR-V', 2010, 1.7, 'Petrol', 'Manual', 115344, 2, 5, 6493)
# ('Kia', 'Rio', 2009, 2.9, 'Diesel', 'Semi-Automatic', 106781, 3, 2, 7564)
# ('Hyundai', 'Sonata', 2011, 1.0, 'Petrol', 'Manual', 279545, 2, 3, 2809)
# ('Chevrolet', 'Equinox', 2006, 2.0, 'Hybrid', 'Automatic', 11585, 5, 4, 10168)
# ('Audi', 'A4', 2017, 2.7, 'Electric', 'Automatic', 172248, 3, 2, 11955)
# ('BMW', '5 Series', 2007, 3.9, 'Hybrid', 'Automatic', 211162, 5, 5, 8376)
# ('Audi', 'A3', 2014, 4.0, 'Petrol', 'Automatic', 182364, 5, 5, 10152)
# ('BMW', '5 Series', 2018, 2.8, 'Petrol', 'Semi-Automatic', 23722, 5, 5, 11825)
# ('Kia', 'Optima', 2018, 1.9, 'Electric', 'Manual', 107386, 5, 4, 11252)
# ('Audi', 'A3', 2017, 1.7, 'Diesel', 'Manual', 156940, 4, 2, 7761)
# ('Toyota', 'Camry', 2017, 4.8, 'Electric', 'Semi-Automatic', 297176, 4, 2, 10056)
# ('Hyundai', 'Sonata', 2011, 4.1, 'Hybrid', 'Semi-Automatic', 138965, 4, 4, 9720)
# ('Volkswagen', 'Tiguan', 2006, 4.4, 'Petrol', 'Automatic', 251894, 2, 4, 6762)
# ('Toyota', 'RAV4', 2013, 3.5, 'Electric', 'Automatic', 85640, 3, 4, 13287)
# ('Mercedes', 'E-Class', 2001, 4.4, 'Hybrid', 'Automatic', 1937, 4, 4, 11261)
# ('Hyundai', 'Elantra', 2022, 4.2, 'Electric', 'Manual', 181600, 3, 3, 13268)
# ('Audi', 'A3', 2021, 4.4, 'Diesel', 'Semi-Automatic', 91956, 2, 2, 12960)
# ('Kia', 'Sportage', 2021, 1.3, 'Hybrid', 'Manual', 197902, 5, 5, 8741)
# ('BMW', '5 Series', 2011, 1.1, 'Diesel', 'Automatic', 178039, 3, 1, 6439)
# ('BMW', '5 Series', 2009, 4.0, 'Electric', 'Automatic', 84645, 2, 2, 12607)
# ('Kia', 'Optima', 2020, 4.1, 'Hybrid', 'Semi-Automatic', 118504, 2, 4, 12829)
# ('Chevrolet', 'Equinox', 2023, 3.0, 'Hybrid', 'Automatic', 230795, 5, 4, 11884)
# ('Chevrolet', 'Malibu', 2008, 2.5, 'Petrol', 'Manual', 94729, 5, 3, 7105)
# ('BMW', '5 Series', 2016, 1.7, 'Petrol', 'Manual', 56150, 3, 1, 9477)
# ('Mercedes', 'C-Class', 2010, 4.7, 'Diesel', 'Semi-Automatic', 256100, 3, 2, 6678)
# ('Volkswagen', 'Golf', 2006, 2.7, 'Hybrid', 'Automatic', 9512, 2, 1, 10909)
# ('Audi', 'A4', 2021, 4.7, 'Diesel', 'Semi-Automatic', 150713, 2, 4, 12085)
# ('Audi', 'Q5', 2018, 1.7, 'Electric', 'Semi-Automatic', 207019, 2, 3, 9059)
# ('Audi', 'A3', 2023, 3.2, 'Petrol', 'Semi-Automatic', 163039, 3, 3, 10939)
# ('Ford', 'Focus', 2016, 1.4, 'Petrol', 'Semi-Automatic', 278559, 5, 4, 4728)
# ('Hyundai', 'Elantra', 2017, 4.2, 'Diesel', 'Automatic', 269154, 3, 2, 9516)
# ('Chevrolet', 'Impala', 2021, 1.3, 'Electric', 'Automatic', 52051, 5, 1, 14158)
# ('Ford', 'Focus', 2013, 2.0, 'Diesel', 'Automatic', 145970, 2, 2, 8580)
# ('BMW', 'X5', 2020, 2.2, 'Electric', 'Automatic', 286174, 4, 5, 10076)
# ('Mercedes', 'E-Class', 2014, 2.5, 'Electric', 'Semi-Automatic', 171683, 3, 2, 9366)
# ('Honda', 'CR-V', 2015, 4.8, 'Diesel', 'Automatic', 295428, 3, 5, 8991)
# ('Honda', 'Accord', 2013, 1.7, 'Petrol', 'Semi-Automatic', 23936, 4, 4, 9221)
# ('Audi', 'Q5', 2002, 2.1, 'Electric', 'Manual', 68076, 4, 1, 7438)
# ('Audi', 'A3', 2018, 2.5, 'Diesel', 'Semi-Automatic', 56429, 2, 1, 10871)
# ('Audi', 'A3', 2014, 2.9, 'Diesel', 'Automatic', 1197, 2, 5, 12676)
# ('Mercedes', 'C-Class', 2021, 1.9, 'Petrol', 'Automatic', 200177, 2, 2, 9796)
# ('BMW', '5 Series', 2002, 4.8, 'Petrol', 'Manual', 249673, 5, 1, 4506)
# ('Mercedes', 'E-Class', 2010, 3.0, 'Electric', 'Manual', 258632, 4, 5, 6927)
# ('Audi', 'Q5', 2003, 3.7, 'Diesel', 'Automatic', 44024, 4, 4, 9319)
# ('Audi', 'Q5', 2022, 1.2, 'Electric', 'Manual', 122902, 2, 3, 11441)
# ('Chevrolet', 'Impala', 2018, 4.0, 'Petrol', 'Manual', 253702, 3, 4, 8425)
# ('Volkswagen', 'Passat', 2005, 1.4, 'Diesel', 'Semi-Automatic', 1841, 2, 2, 6963)
# ('Toyota', 'Corolla', 2016, 4.4, 'Electric', 'Automatic', 256691, 4, 1, 11666)
# ('Mercedes', 'C-Class', 2003, 4.4, 'Hybrid', 'Manual', 88089, 3, 3, 8638)
# ('Ford', 'Fiesta', 2005, 4.7, 'Diesel', 'Semi-Automatic', 295379, 2, 2, 4392)
# ('Chevrolet', 'Malibu', 2012, 2.0, 'Hybrid', 'Automatic', 5356, 2, 3, 12092)
# ('Mercedes', 'GLA', 2020, 4.2, 'Diesel', 'Automatic', 231440, 4, 2, 11171)
# ('Honda', 'Civic', 2010, 3.4, 'Electric', 'Automatic', 139584, 3, 1, 11208)
# ('Kia', 'Sportage', 2001, 4.7, 'Electric', 'Semi-Automatic', 157495, 2, 2, 7950)
# ('Honda', 'CR-V', 2007, 4.8, 'Hybrid', 'Automatic', 132875, 3, 4, 10842)
# ('Volkswagen', 'Golf', 2003, 2.4, 'Petrol', 'Automatic', 145921, 5, 2, 5981)
# ('Kia', 'Rio', 2000, 3.4, 'Diesel', 'Semi-Automatic', 257427, 3, 3, 2351)
# ('Mercedes', 'GLA', 2016, 3.9, 'Petrol', 'Semi-Automatic', 19868, 3, 4, 12402)
# ('Kia', 'Sportage', 2011, 1.8, 'Diesel', 'Automatic', 92188, 2, 4, 8856)
# ('Mercedes', 'GLA', 2013, 3.3, 'Electric', 'Semi-Automatic', 80184, 3, 5, 11696)
# ('Kia', 'Optima', 2005, 4.5, 'Petrol', 'Manual', 18590, 2, 5, 9728)
# ('Audi', 'A4', 2004, 1.0, 'Petrol', 'Manual', 94415, 2, 1, 4411)
# ('Toyota', 'RAV4', 2003, 3.9, 'Electric', 'Automatic', 131868, 5, 3, 9762)
# ('Hyundai', 'Elantra', 2006, 2.8, 'Electric', 'Manual', 110280, 3, 3, 8494)
# ('Mercedes', 'E-Class', 2004, 4.9, 'Petrol', 'Semi-Automatic', 175273, 3, 5, 6694)
# ('Mercedes', 'GLA', 2022, 3.8, 'Diesel', 'Manual', 191466, 3, 2, 10670)
# ('Ford', 'Focus', 2008, 1.8, 'Electric', 'Semi-Automatic', 280713, 3, 1, 4685)
# ('Kia', 'Optima', 2020, 3.2, 'Electric', 'Manual', 88070, 3, 5, 13538)
# ('Honda', 'Civic', 2005, 2.4, 'Petrol', 'Automatic', 60316, 2, 5, 8293)
# ('Ford', 'Fiesta', 2004, 4.0, 'Diesel', 'Automatic', 85348, 3, 3, 9093)
# ('Ford', 'Focus', 2015, 4.8, 'Electric', 'Automatic', 100603, 4, 2, 14887)
# ('Kia', 'Optima', 2008, 4.6, 'Petrol', 'Manual', 164879, 2, 4, 7802)
# ('Toyota', 'Camry', 2007, 4.9, 'Hybrid', 'Manual', 23217, 2, 4, 11635)
# ('Hyundai', 'Sonata', 2017, 1.3, 'Hybrid', 'Automatic', 152123, 5, 5, 9957)
# ('Volkswagen', 'Golf', 2023, 3.5, 'Petrol', 'Semi-Automatic', 139477, 2, 5, 11710)
# ('Honda', 'Civic', 2020, 4.6, 'Petrol', 'Manual', 191397, 3, 4, 10872)
# ('Hyundai', 'Tucson', 2015, 1.6, 'Electric', 'Manual', 259533, 2, 4, 7009)
# ('Ford', 'Focus', 2013, 1.1, 'Diesel', 'Manual', 294516, 4, 1, 3209)
# ('Kia', 'Sportage', 2001, 2.9, 'Diesel', 'Manual', 258813, 4, 5, 2123)
# ('Mercedes', 'E-Class', 2011, 1.8, 'Diesel', 'Semi-Automatic', 261247, 3, 4, 3975)
# ('BMW', '3 Series', 2011, 2.6, 'Petrol', 'Manual', 107928, 4, 2, 7841)
# ('Toyota', 'Corolla', 2014, 2.8, 'Hybrid', 'Automatic', 190214, 5, 2, 9795)
# ('Chevrolet', 'Malibu', 2005, 2.2, 'Diesel', 'Manual', 191462, 2, 4, 3970)
# ('Honda', 'Accord', 2001, 4.0, 'Diesel', 'Manual', 8958, 5, 1, 8220)
# ('Chevrolet', 'Equinox', 2019, 3.9, 'Hybrid', 'Semi-Automatic', 13333, 5, 1, 14433)
# ('Volkswagen', 'Passat', 2010, 3.4, 'Diesel', 'Manual', 8662, 4, 3, 10326)
# ('Honda', 'CR-V', 2018, 3.0, 'Hybrid', 'Semi-Automatic', 180938, 4, 3, 9881)
# ('Mercedes', 'C-Class', 2018, 4.0, 'Petrol', 'Manual', 66347, 3, 2, 12173)
# ('BMW', '3 Series', 2014, 2.1, 'Petrol', 'Manual', 191744, 5, 1, 6565)
# ('Volkswagen', 'Tiguan', 2008, 3.5, 'Petrol', 'Semi-Automatic', 179107, 2, 3, 6417)
# ('Chevrolet', 'Impala', 2009, 1.8, 'Diesel', 'Automatic', 151249, 4, 1, 7075)
# ('Toyota', 'RAV4', 2020, 4.3, 'Hybrid', 'Manual', 187223, 5, 3, 11655)
# ('Mercedes', 'C-Class', 2010, 1.9, 'Petrol', 'Semi-Automatic', 159546, 2, 4, 5809)
# ('Chevrolet', 'Impala', 2013, 4.8, 'Petrol', 'Manual', 206381, 4, 4, 8672)
# ('Honda', 'Civic', 2016, 4.0, 'Diesel', 'Automatic', 175833, 3, 5, 10883)
# ('BMW', '3 Series', 2015, 2.9, 'Electric', 'Automatic', 131766, 2, 3, 12364)
# ('Ford', 'Explorer', 2001, 2.2, 'Petrol', 'Manual', 18630, 3, 5, 6227)
# ('Kia', 'Optima', 2000, 3.7, 'Electric', 'Manual', 166776, 2, 2, 6464)
# ('Kia', 'Sportage', 2007, 1.2, 'Hybrid', 'Automatic', 269614, 3, 4, 4507)
# ('Toyota', 'RAV4', 2001, 4.5, 'Diesel', 'Semi-Automatic', 279971, 3, 1, 3300)
# ('Hyundai', 'Sonata', 2009, 1.0, 'Petrol', 'Manual', 286745, 2, 5, 2065)
# ('Honda', 'Civic', 2013, 3.5, 'Hybrid', 'Semi-Automatic', 93273, 2, 4, 10634)
# ('BMW', 'X5', 2004, 3.7, 'Diesel', 'Semi-Automatic', 110947, 3, 2, 6781)
# ('Honda', 'CR-V', 2018, 1.2, 'Petrol', 'Manual', 166808, 5, 2, 7363)
# ('Chevrolet', 'Equinox', 2009, 2.6, 'Hybrid', 'Semi-Automatic', 264411, 3, 1, 5111)
# ('BMW', 'X5', 2012, 4.3, 'Petrol', 'Manual', 153919, 5, 2, 8921)
# ('Hyundai', 'Sonata', 2020, 1.7, 'Petrol', 'Manual', 11757, 3, 1, 11564)
# ('Hyundai', 'Elantra', 2020, 3.7, 'Hybrid', 'Automatic', 216478, 2, 1, 11970)
# ('Mercedes', 'C-Class', 2003, 2.6, 'Diesel', 'Semi-Automatic', 134567, 5, 2, 4908)
# ('Mercedes', 'C-Class', 2006, 4.5, 'Electric', 'Manual', 162852, 2, 3, 9142)
# ('BMW', '3 Series', 2023, 3.9, 'Hybrid', 'Semi-Automatic', 112480, 2, 2, 13650)
# ('Kia', 'Optima', 2017, 1.9, 'Electric', 'Automatic', 60780, 2, 1, 13384)
# ('Honda', 'CR-V', 2012, 3.2, 'Diesel', 'Automatic', 21520, 4, 4, 11969)
# ('BMW', '5 Series', 2017, 2.1, 'Diesel', 'Automatic', 199006, 3, 3, 8819)
# ('Toyota', 'RAV4', 2006, 1.3, 'Hybrid', 'Manual', 195129, 4, 5, 4297)
# ('Ford', 'Focus', 2003, 3.2, 'Petrol', 'Semi-Automatic', 85005, 3, 1, 6499)
# ('Volkswagen', 'Golf', 2017, 4.3, 'Petrol', 'Automatic', 179528, 2, 5, 11409)
# ('Hyundai', 'Sonata', 2014, 2.3, 'Electric', 'Manual', 1752, 4, 2, 12564)
# ('Mercedes', 'GLA', 2008, 3.2, 'Electric', 'Manual', 25557, 5, 4, 11188)
# ('Ford', 'Focus', 2009, 2.1, 'Petrol', 'Automatic', 122067, 4, 4, 7958)
# ('Hyundai', 'Elantra', 2000, 1.8, 'Petrol', 'Manual', 161487, 3, 5, 2670)
# ('Ford', 'Focus', 2009, 4.1, 'Petrol', 'Automatic', 99562, 5, 2, 10408)
# ('Ford', 'Focus', 2009, 1.2, 'Hybrid', 'Automatic', 114668, 2, 4, 8206)
# ('Toyota', 'Corolla', 2006, 2.8, 'Diesel', 'Semi-Automatic', 174551, 4, 5, 5208)
# ('Chevrolet', 'Malibu', 2006, 2.8, 'Petrol', 'Manual', 253372, 2, 4, 3632)
# ('Mercedes', 'GLA', 2010, 1.9, 'Hybrid', 'Manual', 99563, 3, 5, 8008)
# ('BMW', 'X5', 2010, 4.6, 'Diesel', 'Manual', 79663, 5, 5, 10106)
# ('BMW', 'X5', 2002, 2.9, 'Petrol', 'Manual', 296864, 4, 2, 2000)
# ('Kia', 'Sportage', 2014, 1.4, 'Hybrid', 'Semi-Automatic', 262641, 4, 1, 5447)
# ('Audi', 'Q5', 2023, 4.7, 'Electric', 'Automatic', 222000, 3, 3, 14760)
# ('Ford', 'Focus', 2006, 4.6, 'Petrol', 'Automatic', 98002, 5, 4, 10039)
# ('Kia', 'Sportage', 2000, 3.4, 'Hybrid', 'Manual', 131933, 4, 1, 5861)
# ('BMW', 'X5', 2001, 4.6, 'Diesel', 'Manual', 287045, 4, 4, 3259)
# ('Honda', 'Accord', 2009, 2.7, 'Petrol', 'Manual', 217224, 4, 5, 5155)
# ('Mercedes', 'GLA', 2010, 1.0, 'Hybrid', 'Manual', 296156, 5, 1, 3176)
# ('Toyota', 'Camry', 2013, 2.2, 'Hybrid', 'Manual', 262285, 4, 4, 5954)
# ('Audi', 'A3', 2006, 2.6, 'Diesel', 'Automatic', 282423, 5, 5, 4351)
# ('Ford', 'Fiesta', 2004, 2.2, 'Hybrid', 'Automatic', 256459, 4, 5, 4870)
# ('Kia', 'Sportage', 2021, 2.1, 'Electric', 'Semi-Automatic', 74107, 5, 4, 13017)
# ('Audi', 'A3', 2011, 4.8, 'Petrol', 'Automatic', 80241, 2, 3, 12095)
# ('Toyota', 'Corolla', 2000, 2.0, 'Diesel', 'Manual', 145101, 3, 5, 3197)
# ('Kia', 'Sportage', 2010, 2.3, 'Petrol', 'Manual', 62065, 2, 2, 8158)
# ('Toyota', 'RAV4', 2012, 1.7, 'Petrol', 'Manual', 234785, 3, 1, 4704)
# ('Volkswagen', 'Passat', 2002, 1.8, 'Petrol', 'Manual', 194835, 3, 3, 2603)
# ('Ford', 'Fiesta', 2011, 1.4, 'Hybrid', 'Automatic', 30785, 4, 3, 10684)
# ('Kia', 'Sportage', 2019, 4.0, 'Diesel', 'Semi-Automatic', 50680, 3, 4, 12786)
# ('Toyota', 'RAV4', 2001, 4.7, 'Diesel', 'Semi-Automatic', 230052, 2, 3, 4498)
# ('Honda', 'Civic', 2019, 4.2, 'Petrol', 'Manual', 273193, 2, 4, 8536)
# ('Hyundai', 'Elantra', 2014, 3.4, 'Electric', 'Manual', 227371, 4, 5, 9152)
# ('Toyota', 'Corolla', 2005, 3.2, 'Petrol', 'Automatic', 29885, 2, 2, 9702)
# ('Kia', 'Optima', 2010, 1.2, 'Petrol', 'Automatic', 170847, 4, 4, 6383)
# ('BMW', 'X5', 2001, 4.1, 'Electric', 'Semi-Automatic', 87221, 5, 4, 8755)
# ('Honda', 'Civic', 2020, 4.4, 'Petrol', 'Semi-Automatic', 24913, 3, 3, 14001)
# ('Kia', 'Sportage', 2000, 4.2, 'Hybrid', 'Semi-Automatic', 155444, 3, 5, 6191)
# ('Volkswagen', 'Golf', 2010, 3.9, 'Petrol', 'Automatic', 207380, 2, 5, 8352)
# ('Mercedes', 'C-Class', 2012, 1.5, 'Electric', 'Automatic', 89226, 5, 5, 10915)
# ('BMW', '3 Series', 2001, 4.6, 'Hybrid', 'Manual', 79217, 4, 4, 8415)
# ('Mercedes', 'E-Class', 2010, 3.3, 'Diesel', 'Automatic', 297971, 2, 3, 5940)
# ('Ford', 'Fiesta', 2011, 3.5, 'Diesel', 'Semi-Automatic', 178950, 2, 3, 7321)
# ('Audi', 'A3', 2017, 3.4, 'Electric', 'Automatic', 148880, 3, 5, 13122)
# ('Kia', 'Rio', 2014, 4.4, 'Diesel', 'Semi-Automatic', 90279, 3, 5, 10894)
# ('Chevrolet', 'Impala', 2011, 1.7, 'Diesel', 'Manual', 39156, 3, 1, 8316)
# ('Volkswagen', 'Golf', 2010, 4.5, 'Electric', 'Semi-Automatic', 68014, 3, 2, 12239)
# ('Audi', 'A3', 2019, 2.9, 'Hybrid', 'Manual', 13569, 2, 3, 13428)
# ('BMW', 'X5', 2010, 2.9, 'Petrol', 'Manual', 63026, 2, 5, 8739)
# ('Audi', 'A3', 2012, 4.0, 'Electric', 'Semi-Automatic', 92692, 3, 2, 11846)
# ('Kia', 'Sportage', 2020, 3.0, 'Hybrid', 'Automatic', 98160, 2, 5, 13636)
# ('Ford', 'Explorer', 2006, 1.5, 'Hybrid', 'Semi-Automatic', 94715, 5, 2, 6505)
# ('BMW', '5 Series', 2008, 4.4, 'Hybrid', 'Semi-Automatic', 236894, 2, 1, 7162)
# ('Ford', 'Explorer', 2006, 1.6, 'Hybrid', 'Semi-Automatic', 235768, 5, 2, 3784)
# ('Honda', 'CR-V', 2007, 3.8, 'Electric', 'Automatic', 160230, 4, 2, 10295)
# ('Chevrolet', 'Impala', 2019, 2.5, 'Hybrid', 'Manual', 299406, 3, 1, 7311)
# ('Ford', 'Explorer', 2011, 1.4, 'Petrol', 'Semi-Automatic', 182197, 4, 3, 5156)
# ('Volkswagen', 'Tiguan', 2015, 1.4, 'Electric', 'Semi-Automatic', 235687, 2, 2, 7286)
# ('Kia', 'Rio', 2022, 1.6, 'Diesel', 'Automatic', 295898, 3, 1, 7882)
# ('Kia', 'Sportage', 2001, 3.1, 'Hybrid', 'Automatic', 232603, 4, 4, 5347)
# ('Volkswagen', 'Passat', 2000, 1.8, 'Petrol', 'Automatic', 222084, 2, 3, 2958)
# ('Mercedes', 'E-Class', 2007, 2.4, 'Electric', 'Automatic', 89733, 3, 1, 10305)
# ('Chevrolet', 'Equinox', 2003, 2.0, 'Hybrid', 'Semi-Automatic', 110430, 3, 1, 5791)
# ('Mercedes', 'C-Class', 2002, 3.6, 'Hybrid', 'Automatic', 54815, 3, 5, 9703)
# ('Honda', 'Civic', 2019, 4.0, 'Hybrid', 'Manual', 121403, 5, 2, 12371)
# ('Kia', 'Rio', 2004, 3.6, 'Petrol', 'Semi-Automatic', 168226, 4, 4, 5535)
# ('Kia', 'Rio', 2012, 3.6, 'Petrol', 'Automatic', 244437, 2, 2, 7911)
# ('Kia', 'Sportage', 2016, 2.1, 'Electric', 'Manual', 134097, 4, 5, 10318)
# ('Chevrolet', 'Equinox', 2001, 3.6, 'Hybrid', 'Semi-Automatic', 93140, 2, 1, 7137)
# ('Hyundai', 'Elantra', 2006, 3.0, 'Diesel', 'Automatic', 288209, 3, 2, 4635)
# ('Audi', 'A3', 2020, 1.7, 'Hybrid', 'Semi-Automatic', 54068, 4, 1, 11718)
# ('BMW', '5 Series', 2010, 1.1, 'Petrol', 'Automatic', 1666, 4, 3, 9666)
# ('Toyota', 'Camry', 2004, 2.9, 'Diesel', 'Automatic', 155101, 3, 5, 6597)
# ('Ford', 'Focus', 2020, 1.3, 'Hybrid', 'Manual', 130961, 2, 4, 9780)
# ('Volkswagen', 'Tiguan', 2009, 1.5, 'Electric', 'Semi-Automatic', 204370, 4, 4, 6212)
# ('Chevrolet', 'Equinox', 2004, 3.0, 'Electric', 'Manual', 86109, 3, 5, 8577)
# ('Honda', 'Accord', 2019, 2.1, 'Petrol', 'Automatic', 1068, 2, 1, 13378)
# ('Hyundai', 'Elantra', 2004, 3.1, 'Electric', 'Automatic', 202084, 2, 1, 7858)
# ('Mercedes', 'C-Class', 2011, 4.8, 'Diesel', 'Manual', 120010, 4, 5, 9799)
# ('Mercedes', 'GLA', 2007, 4.8, 'Petrol', 'Semi-Automatic', 77167, 4, 4, 9456)
# ('Ford', 'Explorer', 2015, 4.3, 'Electric', 'Manual', 147409, 3, 1, 11951)
# ('Audi', 'A3', 2005, 2.3, 'Electric', 'Manual', 112828, 3, 2, 7643)
# ('Audi', 'Q5', 2023, 3.5, 'Hybrid', 'Semi-Automatic', 225090, 2, 2, 10998)
# ('Volkswagen', 'Golf', 2003, 2.5, 'Electric', 'Manual', 235804, 3, 1, 4783)
# ('Kia', 'Rio', 2013, 2.7, 'Hybrid', 'Manual', 155927, 5, 4, 8581)
# ('Ford', 'Focus', 2014, 3.8, 'Diesel', 'Semi-Automatic', 91618, 4, 4, 10267)
# ('Ford', 'Explorer', 2008, 4.1, 'Electric', 'Manual', 286699, 3, 5, 6866)
# ('Toyota', 'RAV4', 2013, 3.8, 'Hybrid', 'Automatic', 149662, 2, 1, 11306)
# ('Honda', 'Accord', 2005, 2.8, 'Electric', 'Manual', 228351, 2, 2, 5832)
# ('Kia', 'Rio', 2005, 2.6, 'Diesel', 'Semi-Automatic', 14058, 5, 4, 7918)
# ('Volkswagen', 'Golf', 2023, 1.6, 'Petrol', 'Automatic', 133425, 5, 5, 11431)
# ('Ford', 'Fiesta', 2014, 4.7, 'Petrol', 'Semi-Automatic', 85892, 5, 2, 11282)
# ('Ford', 'Explorer', 2006, 3.1, 'Electric', 'Semi-Automatic', 252610, 2, 3, 5947)
# ('Mercedes', 'GLA', 2018, 2.0, 'Hybrid', 'Automatic', 119566, 5, 5, 11608)
# ('Ford', 'Fiesta', 2007, 3.4, 'Electric', 'Manual', 125769, 3, 1, 9084)
# ('Hyundai', 'Sonata', 2007, 2.3, 'Electric', 'Manual', 76257, 2, 3, 8974)
# ('Ford', 'Fiesta', 2009, 2.4, 'Petrol', 'Automatic', 22624, 4, 4, 10247)
# ('Ford', 'Explorer', 2007, 1.1, 'Diesel', 'Semi-Automatic', 261935, 4, 2, 2061)
# ('Mercedes', 'GLA', 2018, 4.8, 'Hybrid', 'Automatic', 108824, 3, 4, 14623)
# ('Honda', 'CR-V', 2001, 4.3, 'Petrol', 'Semi-Automatic', 67506, 3, 4, 7349)
# ('Mercedes', 'C-Class', 2013, 1.5, 'Hybrid', 'Automatic', 198747, 5, 4, 8025)
# ('Kia', 'Rio', 2006, 4.9, 'Electric', 'Manual', 32528, 4, 3, 12149)
# ('Ford', 'Fiesta', 2011, 5.0, 'Petrol', 'Automatic', 125014, 4, 5, 11399)
# ('BMW', 'X5', 2007, 2.0, 'Electric', 'Automatic', 225309, 2, 5, 7193)
# ('BMW', 'X5', 2007, 2.1, 'Electric', 'Manual', 48326, 5, 4, 9333)
# ('Ford', 'Fiesta', 2012, 3.4, 'Electric', 'Automatic', 66901, 3, 3, 13261)
# ('Ford', 'Explorer', 2001, 1.1, 'Hybrid', 'Manual', 221586, 3, 5, 2068)
# ('Toyota', 'Corolla', 2014, 4.7, 'Petrol', 'Semi-Automatic', 114382, 5, 3, 10712)
# ('Mercedes', 'C-Class', 2007, 2.0, 'Petrol', 'Semi-Automatic', 118689, 5, 1, 5826)
# ('Audi', 'A4', 2022, 1.4, 'Electric', 'Manual', 84573, 3, 4, 12408)
# ('BMW', '3 Series', 2001, 4.7, 'Diesel', 'Semi-Automatic', 107974, 3, 3, 6940)
# ('Mercedes', 'GLA', 2003, 2.2, 'Hybrid', 'Semi-Automatic', 17393, 3, 5, 7852)
# ('Volkswagen', 'Golf', 2022, 4.1, 'Hybrid', 'Semi-Automatic', 15423, 4, 3, 15491)
# ('Volkswagen', 'Tiguan', 2009, 2.1, 'Diesel', 'Automatic', 216808, 5, 1, 6063)
# ('BMW', '3 Series', 2001, 4.2, 'Electric', 'Automatic', 271492, 5, 3, 6670)
# ('Toyota', 'Corolla', 2015, 4.9, 'Electric', 'Manual', 292193, 5, 2, 9656)
# ('Mercedes', 'C-Class', 2020, 1.2, 'Petrol', 'Manual', 100045, 5, 5, 9299)
# ('Toyota', 'Corolla', 2018, 3.5, 'Petrol', 'Automatic', 230823, 3, 5, 9883)
# ('Ford', 'Fiesta', 2020, 2.9, 'Hybrid', 'Automatic', 123389, 4, 4, 13032)
# ('Honda', 'Civic', 2018, 2.2, 'Hybrid', 'Automatic', 227142, 5, 3, 9657)
# ('Kia', 'Sportage', 2001, 3.3, 'Electric', 'Semi-Automatic', 258462, 4, 4, 4530)
# ('Hyundai', 'Sonata', 2020, 3.4, 'Hybrid', 'Automatic', 15353, 3, 4, 15692)
# ('Volkswagen', 'Passat', 2006, 3.3, 'Hybrid', 'Semi-Automatic', 203140, 3, 1, 6137)
# ('Hyundai', 'Tucson', 2017, 4.3, 'Diesel', 'Semi-Automatic', 190312, 5, 2, 9693)
# ('Kia', 'Sportage', 2003, 2.3, 'Diesel', 'Automatic', 138463, 5, 1, 6030)
# ('Volkswagen', 'Tiguan', 2011, 4.2, 'Hybrid', 'Manual', 49206, 5, 5, 11615)
# ('Volkswagen', 'Tiguan', 2019, 3.9, 'Electric', 'Manual', 133300, 4, 1, 13034)
# ('Honda', 'Accord', 2020, 3.6, 'Hybrid', 'Semi-Automatic', 51251, 5, 5, 13674)
# ('BMW', 'X5', 2021, 1.7, 'Petrol', 'Semi-Automatic', 48231, 5, 2, 11135)
# ('Ford', 'Explorer', 2010, 1.6, 'Petrol', 'Manual', 36425, 3, 4, 7971)
# ('Hyundai', 'Sonata', 2022, 3.1, 'Hybrid', 'Automatic', 28342, 3, 5, 15733)
# ('Volkswagen', 'Golf', 2016, 2.8, 'Hybrid', 'Automatic', 218978, 2, 1, 9820)
# ('Ford', 'Fiesta', 2014, 2.8, 'Electric', 'Semi-Automatic', 136710, 5, 1, 10365)
# ('Hyundai', 'Elantra', 2001, 4.1, 'Petrol', 'Manual', 187046, 2, 3, 4759)
# ('Hyundai', 'Elantra', 2005, 2.7, 'Hybrid', 'Automatic', 45510, 2, 3, 9889)
# ('BMW', 'X5', 2011, 3.3, 'Hybrid', 'Semi-Automatic', 59350, 5, 1, 10513)
# ('Toyota', 'Camry', 2005, 4.4, 'Petrol', 'Automatic', 124854, 4, 2, 9002)
# ('Honda', 'Accord', 2002, 1.7, 'Hybrid', 'Manual', 129658, 4, 2, 4806)
# ('Ford', 'Explorer', 2017, 5.0, 'Electric', 'Semi-Automatic', 174286, 4, 1, 12714)
# ('Chevrolet', 'Equinox', 2017, 1.8, 'Petrol', 'Semi-Automatic', 96482, 5, 5, 9070)
# ('Honda', 'Civic', 2015, 2.3, 'Electric', 'Semi-Automatic', 207427, 4, 5, 8751)
# ('Chevrolet', 'Impala', 2023, 2.1, 'Petrol', 'Automatic', 41573, 5, 4, 13768)
# ('Chevrolet', 'Equinox', 2003, 3.3, 'Hybrid', 'Automatic', 100141, 2, 3, 8797)
# ('Mercedes', 'E-Class', 2004, 1.2, 'Diesel', 'Automatic', 141943, 4, 1, 5161)
# ('Volkswagen', 'Passat', 2015, 4.2, 'Petrol', 'Automatic', 263711, 3, 2, 9025)
# ('Chevrolet', 'Malibu', 2000, 2.8, 'Petrol', 'Manual', 280108, 5, 3, 2000)
# ('BMW', '3 Series', 2011, 2.8, 'Hybrid', 'Manual', 178509, 4, 4, 7629)
# ('Hyundai', 'Sonata', 2004, 4.0, 'Petrol', 'Manual', 17140, 5, 2, 8957)
# ('Kia', 'Rio', 2021, 1.4, 'Hybrid', 'Manual', 115527, 4, 1, 10489)
# ('BMW', '5 Series', 2020, 4.1, 'Hybrid', 'Automatic', 65158, 3, 1, 15396)
# ('Honda', 'Accord', 2023, 5.0, 'Petrol', 'Manual', 238324, 5, 2, 11233)
# ('Audi', 'A4', 2022, 4.6, 'Hybrid', 'Semi-Automatic', 226584, 2, 4, 11768)
# ('Volkswagen', 'Tiguan', 2017, 2.6, 'Hybrid', 'Automatic', 233248, 5, 1, 9635)
# ('Audi', 'Q5', 2019, 1.4, 'Diesel', 'Automatic', 280967, 2, 3, 7080)
# ('Ford', 'Fiesta', 2006, 2.7, 'Hybrid', 'Manual', 51538, 2, 2, 8569)
# ('BMW', 'X5', 2009, 3.1, 'Petrol', 'Manual', 65564, 2, 4, 8588)
# ('Hyundai', 'Tucson', 2021, 3.9, 'Diesel', 'Automatic', 217374, 2, 4, 11452)
# ('Honda', 'Civic', 2019, 3.2, 'Diesel', 'Manual', 158300, 3, 2, 9834)
# ('Chevrolet', 'Malibu', 2022, 4.8, 'Hybrid', 'Semi-Automatic', 117267, 2, 4, 14154)
# ('Mercedes', 'E-Class', 2014, 1.7, 'Petrol', 'Manual', 95579, 3, 3, 8088)
# ('Volkswagen', 'Golf', 2010, 3.1, 'Hybrid', 'Semi-Automatic', 265548, 5, 4, 5889)
# ('Toyota', 'RAV4', 2007, 4.9, 'Hybrid', 'Semi-Automatic', 193478, 2, 4, 8230)
# ('Volkswagen', 'Golf', 2022, 4.6, 'Diesel', 'Manual', 145259, 2, 3, 12394)
# ('Hyundai', 'Tucson', 2022, 1.3, 'Diesel', 'Semi-Automatic', 86670, 2, 4, 10266)
# ('Volkswagen', 'Passat', 2005, 1.6, 'Electric', 'Automatic', 293339, 5, 1, 4833)
# ('Audi', 'A3', 2008, 3.5, 'Diesel', 'Manual', 79861, 4, 1, 8402)
# ('Mercedes', 'C-Class', 2020, 1.9, 'Petrol', 'Semi-Automatic', 288000, 4, 5, 6240)
# ('Toyota', 'RAV4', 2005, 2.5, 'Hybrid', 'Semi-Automatic', 239287, 4, 1, 4314)
# ('Volkswagen', 'Tiguan', 2002, 3.4, 'Diesel', 'Automatic', 152117, 3, 2, 6557)
# ('Kia', 'Sportage', 2019, 4.4, 'Petrol', 'Manual', 195296, 5, 4, 10294)
# ('Honda', 'CR-V', 2000, 3.6, 'Petrol', 'Manual', 230409, 2, 3, 3091)
# ('Honda', 'Civic', 2014, 1.1, 'Diesel', 'Automatic', 106397, 4, 2, 8772)
# ('Volkswagen', 'Passat', 2007, 3.7, 'Electric', 'Manual', 295514, 2, 4, 5989)
# ('Toyota', 'Corolla', 2016, 3.7, 'Petrol', 'Manual', 59160, 5, 2, 11416)
# ('Chevrolet', 'Equinox', 2016, 2.3, 'Petrol', 'Semi-Automatic', 73775, 3, 4, 9724)
# ('Hyundai', 'Tucson', 2002, 2.6, 'Petrol', 'Semi-Automatic', 11401, 5, 4, 7071)
# ('Chevrolet', 'Impala', 2019, 4.4, 'Diesel', 'Semi-Automatic', 233465, 2, 1, 9530)
# ('Volkswagen', 'Golf', 2016, 4.3, 'Petrol', 'Semi-Automatic', 240885, 3, 2, 8382)
# ('Hyundai', 'Elantra', 2018, 3.7, 'Electric', 'Semi-Automatic', 205909, 3, 2, 11081)
# ('Ford', 'Explorer', 2011, 1.4, 'Hybrid', 'Semi-Automatic', 161912, 4, 4, 6561)
# ('Hyundai', 'Elantra', 2019, 3.3, 'Electric', 'Manual', 128619, 3, 5, 12527)
# ('Toyota', 'Corolla', 2019, 4.2, 'Electric', 'Semi-Automatic', 253093, 5, 4, 10938)
# ('Chevrolet', 'Malibu', 2022, 4.8, 'Petrol', 'Semi-Automatic', 97890, 2, 2, 13542)
# ('Toyota', 'Camry', 2016, 1.2, 'Diesel', 'Manual', 157466, 4, 1, 6950)
# ('Audi', 'A3', 2009, 1.2, 'Petrol', 'Automatic', 275586, 3, 5, 3988)
# ('Volkswagen', 'Tiguan', 2006, 2.6, 'Electric', 'Manual', 219205, 5, 5, 6115)
# ('Mercedes', 'E-Class', 2018, 1.6, 'Hybrid', 'Manual', 78445, 4, 4, 10531)
# ('Hyundai', 'Sonata', 2009, 4.4, 'Hybrid', 'Semi-Automatic', 282931, 5, 3, 6541)
# ('Volkswagen', 'Passat', 2023, 3.0, 'Hybrid', 'Automatic', 242006, 5, 1, 11659)
# ('Kia', 'Sportage', 2002, 4.4, 'Petrol', 'Automatic', 54982, 5, 5, 9500)
# ('Chevrolet', 'Malibu', 2003, 1.2, 'Diesel', 'Semi-Automatic', 53980, 4, 3, 5120)
# ('Ford', 'Explorer', 2019, 1.6, 'Hybrid', 'Semi-Automatic', 84291, 4, 4, 10714)
# ('Honda', 'Accord', 2000, 2.8, 'Electric', 'Automatic', 128713, 4, 2, 7825)
# ('Honda', 'Accord', 2007, 1.7, 'Electric', 'Automatic', 197700, 2, 4, 7446)
# ('Ford', 'Explorer', 2005, 1.9, 'Diesel', 'Semi-Automatic', 103956, 5, 2, 5420)
# ('Kia', 'Sportage', 2011, 1.7, 'Hybrid', 'Manual', 264104, 4, 2, 4817)
# ('Kia', 'Optima', 2012, 2.7, 'Electric', 'Automatic', 188249, 3, 4, 10135)
# ('Audi', 'A4', 2021, 3.6, 'Diesel', 'Semi-Automatic', 252284, 5, 4, 8954)
# ('Ford', 'Fiesta', 2016, 3.6, 'Diesel', 'Manual', 292131, 4, 4, 6657)
# ('Kia', 'Rio', 2007, 4.7, 'Electric', 'Manual', 18622, 4, 3, 12527)
# ('Honda', 'Civic', 2001, 1.8, 'Electric', 'Semi-Automatic', 38814, 4, 5, 7423)
# ('Volkswagen', 'Golf', 2001, 2.3, 'Diesel', 'Manual', 64027, 3, 2, 5419)
# ('Chevrolet', 'Equinox', 2004, 2.6, 'Hybrid', 'Semi-Automatic', 234638, 5, 3, 4207)
# ('Ford', 'Focus', 2006, 4.4, 'Hybrid', 'Automatic', 213796, 4, 4, 8524)
# ('Hyundai', 'Elantra', 2008, 4.5, 'Electric', 'Semi-Automatic', 242378, 4, 3, 8152)
# ('Kia', 'Optima', 2015, 3.4, 'Electric', 'Manual', 68256, 4, 2, 12634)
# ('Ford', 'Fiesta', 2014, 4.7, 'Electric', 'Automatic', 262198, 4, 2, 11256)
# ('Hyundai', 'Elantra', 2014, 3.7, 'Petrol', 'Semi-Automatic', 203553, 3, 5, 7928)
# ('Ford', 'Focus', 2010, 3.9, 'Hybrid', 'Automatic', 42902, 3, 5, 12641)
# ('Audi', 'A4', 2020, 4.8, 'Electric', 'Manual', 116761, 2, 3, 14564)
# ('Volkswagen', 'Tiguan', 2019, 4.7, 'Petrol', 'Semi-Automatic', 213300, 4, 1, 10234)
# ('Honda', 'Accord', 2000, 2.9, 'Hybrid', 'Semi-Automatic', 238272, 5, 1, 3234)
# ('BMW', 'X5', 2021, 5.0, 'Petrol', 'Semi-Automatic', 98604, 2, 4, 13427)
# ('Hyundai', 'Tucson', 2004, 4.2, 'Hybrid', 'Manual', 271816, 3, 5, 5063)
# ('Audi', 'A4', 2020, 1.3, 'Hybrid', 'Manual', 282883, 4, 1, 6742)
# ('BMW', '5 Series', 2020, 2.7, 'Hybrid', 'Semi-Automatic', 109271, 3, 4, 11614)
# ('Honda', 'CR-V', 2020, 2.4, 'Hybrid', 'Manual', 103185, 2, 3, 11436)
# ('BMW', 'X5', 2000, 1.1, 'Hybrid', 'Automatic', 141537, 3, 2, 4869)
# ('BMW', '5 Series', 2012, 1.7, 'Petrol', 'Automatic', 163543, 5, 4, 7629)
# ('Kia', 'Rio', 2021, 3.6, 'Petrol', 'Automatic', 79401, 4, 3, 13911)
# ('Hyundai', 'Sonata', 2009, 4.1, 'Diesel', 'Manual', 67077, 2, 5, 9558)
# ('Ford', 'Focus', 2010, 1.2, 'Electric', 'Automatic', 220484, 4, 4, 7390)
# ('Volkswagen', 'Tiguan', 2006, 3.1, 'Electric', 'Automatic', 135166, 5, 1, 9796)
# ('Audi', 'A3', 2002, 3.2, 'Hybrid', 'Automatic', 106780, 2, 5, 8264)
# ('Mercedes', 'C-Class', 2017, 2.3, 'Electric', 'Semi-Automatic', 40455, 4, 1, 12690)
# ('Honda', 'CR-V', 2015, 2.2, 'Electric', 'Manual', 164031, 4, 5, 9519)
# ('Hyundai', 'Tucson', 2010, 3.6, 'Diesel', 'Semi-Automatic', 37887, 5, 5, 9942)
# ('Kia', 'Optima', 2003, 1.5, 'Electric', 'Automatic', 243023, 2, 3, 5139)
# ('Chevrolet', 'Impala', 2018, 3.9, 'Hybrid', 'Automatic', 22059, 4, 3, 15458)
# ('BMW', '5 Series', 2016, 3.1, 'Petrol', 'Automatic', 82589, 2, 3, 11848)
# ('Mercedes', 'GLA', 2005, 3.5, 'Hybrid', 'Manual', 254719, 4, 4, 5005)
# ('Toyota', 'Camry', 2014, 2.8, 'Petrol', 'Semi-Automatic', 277899, 2, 5, 5542)
# ('Hyundai', 'Elantra', 2010, 4.5, 'Hybrid', 'Manual', 93756, 3, 1, 10724)
# ('Ford', 'Explorer', 2005, 2.1, 'Electric', 'Automatic', 40020, 5, 2, 10399)
# ('Mercedes', 'E-Class', 2003, 1.9, 'Petrol', 'Automatic', 211135, 5, 1, 4177)
# ('Kia', 'Sportage', 2017, 3.4, 'Diesel', 'Manual', 149589, 2, 2, 9608)
# ('Hyundai', 'Sonata', 2002, 2.4, 'Petrol', 'Automatic', 122979, 3, 5, 6140)
# ('Audi', 'A4', 2018, 1.6, 'Diesel', 'Manual', 180019, 3, 5, 7499)
# ('Ford', 'Fiesta', 2001, 2.6, 'Electric', 'Semi-Automatic', 74, 2, 2, 8998)
# ('Toyota', 'Corolla', 2014, 1.2, 'Electric', 'Automatic', 215776, 4, 4, 8684)
# ('BMW', '5 Series', 2017, 2.7, 'Electric', 'Automatic', 23058, 2, 3, 14938)
# ('Kia', 'Sportage', 2020, 2.7, 'Diesel', 'Automatic', 87168, 5, 3, 12556)
# ('Honda', 'Civic', 2007, 3.0, 'Diesel', 'Manual', 45399, 3, 1, 8292)
# ('Honda', 'CR-V', 2004, 3.9, 'Electric', 'Automatic', 96421, 4, 5, 10771)
# ('Toyota', 'RAV4', 2002, 1.7, 'Petrol', 'Automatic', 265079, 4, 4, 2598)
# ('Volkswagen', 'Tiguan', 2023, 4.6, 'Diesel', 'Automatic', 193427, 3, 1, 13231)
# ('Audi', 'Q5', 2019, 1.5, 'Hybrid', 'Automatic', 299007, 2, 2, 7819)
# ('Mercedes', 'E-Class', 2015, 2.4, 'Diesel', 'Semi-Automatic', 260513, 4, 5, 5789)
# ('Chevrolet', 'Impala', 2013, 2.2, 'Electric', 'Automatic', 196832, 3, 1, 9763)
# ('Audi', 'Q5', 2014, 4.0, 'Petrol', 'Semi-Automatic', 237177, 2, 4, 7556)
# ('Volkswagen', 'Tiguan', 2011, 4.9, 'Petrol', 'Semi-Automatic', 285572, 2, 4, 6588)
# ('Ford', 'Focus', 2017, 3.6, 'Petrol', 'Semi-Automatic', 263823, 5, 4, 7523)
# ('BMW', '3 Series', 2019, 3.2, 'Electric', 'Manual', 248880, 5, 5, 10022)
# ('Toyota', 'Corolla', 2001, 4.8, 'Electric', 'Semi-Automatic', 107723, 2, 3, 9045)
# ('Audi', 'A4', 2011, 2.8, 'Petrol', 'Manual', 104757, 3, 5, 8104)
# ('BMW', '5 Series', 2018, 3.9, 'Electric', 'Manual', 216924, 5, 3, 11061)
# ('BMW', '3 Series', 2012, 4.1, 'Hybrid', 'Semi-Automatic', 269110, 5, 5, 7417)
# ('Kia', 'Rio', 2006, 1.1, 'Hybrid', 'Automatic', 71600, 2, 2, 8068)
# ('Mercedes', 'C-Class', 2020, 2.3, 'Electric', 'Manual', 167084, 3, 4, 11058)
# ('Volkswagen', 'Passat', 2018, 3.5, 'Electric', 'Manual', 44918, 4, 3, 14101)
# ('Audi', 'A4', 2009, 4.5, 'Petrol', 'Automatic', 119948, 3, 3, 10401)
# ('Mercedes', 'GLA', 2002, 4.6, 'Electric', 'Automatic', 28405, 5, 4, 12231)
# ('Chevrolet', 'Malibu', 2002, 1.7, 'Electric', 'Manual', 214459, 5, 1, 4110)
# ('Audi', 'A4', 2017, 2.6, 'Petrol', 'Automatic', 280103, 4, 5, 7697)
# ('Mercedes', 'GLA', 2012, 4.7, 'Electric', 'Semi-Automatic', 251019, 2, 3, 9379)
# ('Audi', 'A4', 2018, 3.3, 'Hybrid', 'Manual', 171346, 2, 1, 10373)
# ('BMW', '3 Series', 2011, 3.9, 'Petrol', 'Automatic', 31189, 3, 3, 12176)
# ('Chevrolet', 'Malibu', 2001, 4.9, 'Petrol', 'Manual', 70195, 2, 2, 7896)
# ('Mercedes', 'C-Class', 2015, 4.4, 'Hybrid', 'Semi-Automatic', 139468, 5, 4, 11210)
# ('Chevrolet', 'Impala', 2005, 3.1, 'Hybrid', 'Semi-Automatic', 42542, 2, 4, 8849)
# ('Hyundai', 'Tucson', 2020, 2.3, 'Hybrid', 'Semi-Automatic', 192030, 4, 1, 9559)
# ('BMW', '3 Series', 2004, 3.0, 'Electric', 'Manual', 215571, 3, 5, 5988)
# ('Toyota', 'Corolla', 2017, 1.6, 'Electric', 'Semi-Automatic', 46400, 3, 3, 11872)
# ('Honda', 'Civic', 2002, 4.3, 'Diesel', 'Manual', 275483, 4, 1, 3490)
# ('Kia', 'Rio', 2004, 3.7, 'Diesel', 'Automatic', 68962, 4, 5, 9120)
# ('Honda', 'Accord', 2003, 2.2, 'Electric', 'Manual', 278555, 2, 3, 3628)
# ('BMW', '5 Series', 2018, 4.6, 'Diesel', 'Manual', 193942, 3, 1, 10221)
# ('Honda', 'Civic', 2008, 4.5, 'Hybrid', 'Automatic', 140691, 3, 1, 10686)
# ('Kia', 'Optima', 2021, 1.6, 'Diesel', 'Semi-Automatic', 109050, 2, 5, 9819)
# ('Mercedes', 'E-Class', 2000, 1.1, 'Diesel', 'Manual', 233776, 2, 3, 2000)
# ('Chevrolet', 'Equinox', 2015, 1.3, 'Hybrid', 'Semi-Automatic', 117006, 3, 5, 8559)
# ('Honda', 'CR-V', 2016, 4.4, 'Petrol', 'Automatic', 7588, 4, 5, 14648)
# ('Chevrolet', 'Impala', 2006, 4.4, 'Diesel', 'Automatic', 191716, 2, 3, 7965)
# ('Mercedes', 'E-Class', 2000, 2.5, 'Diesel', 'Manual', 18150, 3, 5, 6237)
# ('Mercedes', 'GLA', 2006, 3.5, 'Electric', 'Semi-Automatic', 25049, 4, 5, 10899)
# ('Ford', 'Focus', 2015, 1.9, 'Electric', 'Manual', 50573, 4, 5, 11488)
# ('Hyundai', 'Elantra', 2008, 2.7, 'Electric', 'Automatic', 1708, 5, 2, 12665)
# ('Ford', 'Fiesta', 2010, 1.1, 'Hybrid', 'Manual', 98700, 5, 3, 7226)
# ('Kia', 'Optima', 2006, 4.6, 'Hybrid', 'Manual', 272450, 4, 3, 6051)
# ('Hyundai', 'Sonata', 2002, 3.1, 'Hybrid', 'Semi-Automatic', 264010, 5, 1, 3519)
# ('Hyundai', 'Tucson', 2002, 4.4, 'Petrol', 'Manual', 253283, 4, 1, 4034)
# ('Volkswagen', 'Passat', 2002, 3.1, 'Diesel', 'Automatic', 153222, 5, 2, 6235)
# ('BMW', '3 Series', 2004, 3.0, 'Electric', 'Semi-Automatic', 140269, 4, 1, 7494)
# ('Toyota', 'Corolla', 2022, 4.6, 'Diesel', 'Automatic', 48034, 3, 1, 15839)
# ('BMW', '3 Series', 2012, 4.5, 'Petrol', 'Semi-Automatic', 78159, 3, 1, 10636)
# ('Audi', 'Q5', 2021, 3.0, 'Diesel', 'Semi-Automatic', 226346, 5, 4, 8873)
# ('Toyota', 'Camry', 2014, 4.1, 'Diesel', 'Automatic', 35164, 3, 3, 13196)
# ('Kia', 'Rio', 2016, 1.6, 'Electric', 'Automatic', 285860, 4, 5, 8282)
# ('Honda', 'CR-V', 2000, 3.5, 'Hybrid', 'Semi-Automatic', 181019, 2, 2, 4979)
# ('Honda', 'CR-V', 2012, 4.9, 'Electric', 'Manual', 4608, 3, 2, 14507)
# ('Audi', 'A4', 2007, 1.4, 'Petrol', 'Manual', 252417, 3, 3, 2551)
# ('Mercedes', 'C-Class', 2015, 2.7, 'Diesel', 'Manual', 181326, 5, 5, 7673)
# ('Toyota', 'RAV4', 2015, 2.0, 'Diesel', 'Manual', 125458, 2, 3, 8090)
# ('Hyundai', 'Sonata', 2011, 2.5, 'Petrol', 'Manual', 61333, 2, 1, 8673)
# ('BMW', 'X5', 2009, 3.8, 'Electric', 'Automatic', 103338, 3, 3, 12033)
# ('Hyundai', 'Elantra', 2019, 1.9, 'Electric', 'Automatic', 44978, 4, 4, 14300)
# ('Honda', 'Accord', 2002, 2.5, 'Electric', 'Automatic', 119657, 2, 2, 8306)
# ('Ford', 'Explorer', 2003, 2.2, 'Electric', 'Manual', 106537, 4, 4, 7069)
# ('Volkswagen', 'Golf', 2000, 1.0, 'Hybrid', 'Semi-Automatic', 156258, 4, 1, 2974)
# ('Mercedes', 'C-Class', 2022, 3.6, 'Diesel', 'Manual', 233628, 5, 2, 9627)
# ('Chevrolet', 'Malibu', 2023, 2.0, 'Diesel', 'Manual', 280794, 2, 3, 7384)
# ('Audi', 'A3', 2018, 3.3, 'Hybrid', 'Semi-Automatic', 274434, 3, 2, 8311)
# ('Chevrolet', 'Equinox', 2015, 3.2, 'Diesel', 'Automatic', 60419, 4, 4, 12091)
# ('Mercedes', 'GLA', 2019, 2.9, 'Petrol', 'Semi-Automatic', 247451, 3, 3, 7750)
# ('Ford', 'Focus', 2009, 3.0, 'Diesel', 'Manual', 54105, 3, 2, 8717)
# ('Chevrolet', 'Impala', 2010, 1.8, 'Hybrid', 'Manual', 227999, 5, 1, 5340)
# ('Hyundai', 'Elantra', 2022, 2.8, 'Diesel', 'Automatic', 250524, 5, 5, 9989)
# ('Audi', 'A4', 2021, 2.7, 'Petrol', 'Manual', 283597, 2, 2, 7428)
# ('Toyota', 'Camry', 2010, 4.7, 'Petrol', 'Semi-Automatic', 155338, 5, 1, 8693)
# ('Honda', 'CR-V', 2004, 1.3, 'Electric', 'Automatic', 189304, 5, 1, 6313)
# ('Audi', 'A3', 2019, 3.1, 'Diesel', 'Semi-Automatic', 171550, 3, 5, 9469)
# ('Chevrolet', 'Malibu', 2011, 4.8, 'Electric', 'Automatic', 49802, 2, 4, 14703)
# ('Kia', 'Rio', 2002, 3.3, 'Diesel', 'Automatic', 252871, 3, 2, 4442)
# ('Volkswagen', 'Golf', 2012, 1.5, 'Electric', 'Semi-Automatic', 19946, 5, 4, 10801)
# ('Toyota', 'RAV4', 2016, 1.5, 'Electric', 'Semi-Automatic', 34256, 4, 3, 11714)
# ('Volkswagen', 'Tiguan', 2012, 2.8, 'Diesel', 'Manual', 22534, 5, 2, 10049)
# ('Audi', 'A4', 2009, 3.3, 'Electric', 'Semi-Automatic', 105672, 5, 2, 9986)
# ('Ford', 'Focus', 2013, 3.5, 'Electric', 'Manual', 184223, 2, 1, 9815)
# ('Mercedes', 'GLA', 2005, 3.8, 'Electric', 'Automatic', 159958, 5, 2, 9700)
# ('Hyundai', 'Tucson', 2020, 2.7, 'Petrol', 'Automatic', 130146, 2, 3, 11697)
# ('Audi', 'Q5', 2017, 3.4, 'Petrol', 'Semi-Automatic', 184285, 4, 3, 8914)
# ('Volkswagen', 'Tiguan', 2017, 3.3, 'Electric', 'Automatic', 201512, 4, 3, 11969)
# ('Kia', 'Sportage', 2014, 1.3, 'Diesel', 'Semi-Automatic', 180373, 5, 5, 5992)
# ('Chevrolet', 'Impala', 2004, 1.8, 'Diesel', 'Semi-Automatic', 149851, 4, 2, 4102)
# ('Honda', 'CR-V', 2016, 3.2, 'Diesel', 'Manual', 253949, 5, 1, 7021)
# ('Ford', 'Focus', 2001, 4.1, 'Diesel', 'Semi-Automatic', 88202, 2, 5, 6735)
# ('Volkswagen', 'Golf', 2010, 4.6, 'Hybrid', 'Semi-Automatic', 89735, 5, 5, 10905)
# ('Chevrolet', 'Malibu', 2015, 4.3, 'Petrol', 'Semi-Automatic', 190674, 4, 1, 9086)
# ('Kia', 'Sportage', 2015, 3.5, 'Diesel', 'Manual', 118075, 2, 3, 9738)
# ('BMW', '5 Series', 2023, 1.8, 'Electric', 'Semi-Automatic', 212962, 2, 4, 10540)
# ('Ford', 'Explorer', 2000, 1.8, 'Hybrid', 'Manual', 222734, 3, 4, 2445)
# ...
# ('Chevrolet', 'Equinox', 2017, 1.2, 'Diesel', 'Automatic', 270746, 2, 1, 6485)
# ('Mercedes', 'E-Class', 2007, 2.6, 'Hybrid', 'Manual', 263333, 4, 4, 4533)
# ('Honda', 'CR-V', 2023, 3.2, 'Electric', 'Semi-Automatic', 230001, 5, 2, 11599)
# ('BMW', 'X5', 2005, 1.8, 'Hybrid', 'Semi-Automatic', 273362, 3, 3, 2932)
# ('Hyundai', 'Elantra', 2023, 1.8, 'Electric', 'Manual', 170719, 3, 2, 11385)
# ('Mercedes', 'GLA', 2012, 2.6, 'Diesel', 'Automatic', 31130, 4, 5, 11177)
# ('Mercedes', 'E-Class', 2005, 4.3, 'Petrol', 'Semi-Automatic', 133242, 5, 4, 7235)
# ('Audi', 'Q5', 2020, 4.1, 'Diesel', 'Automatic', 46625, 4, 4, 14767)
# ('BMW', '5 Series', 2002, 2.4, 'Hybrid', 'Automatic', 172380, 2, 1, 6152)
# ('Ford', 'Focus', 2017, 2.3, 'Diesel', 'Semi-Automatic', 76234, 4, 5, 9975)
# ('Toyota', 'Camry', 2007, 4.6, 'Diesel', 'Automatic', 192632, 2, 3, 8447)
# ('Mercedes', 'GLA', 2015, 2.6, 'Diesel', 'Automatic', 187667, 2, 1, 8946)
# ('Honda', 'Accord', 2005, 4.1, 'Electric', 'Manual', 97179, 5, 5, 9756)
# ('Honda', 'Accord', 2019, 3.7, 'Diesel', 'Automatic', 266134, 5, 2, 9677)
# ('Chevrolet', 'Equinox', 2011, 3.4, 'Diesel', 'Automatic', 165710, 3, 5, 8985)
# ('Toyota', 'RAV4', 2000, 2.0, 'Petrol', 'Semi-Automatic', 61667, 3, 5, 4866)
# ('Hyundai', 'Sonata', 2013, 1.7, 'Petrol', 'Manual', 102433, 3, 3, 7651)
# ('Mercedes', 'GLA', 2015, 4.9, 'Electric', 'Automatic', 14529, 2, 5, 16709)
# ('Audi', 'A4', 2005, 2.0, 'Petrol', 'Automatic', 153520, 5, 2, 6029)
# ('Chevrolet', 'Equinox', 2003, 4.7, 'Electric', 'Manual', 20152, 2, 1, 11296)
# ('Audi', 'Q5', 2005, 4.5, 'Hybrid', 'Automatic', 227044, 4, 2, 8059)
# ('Chevrolet', 'Malibu', 2013, 1.5, 'Diesel', 'Semi-Automatic', 203936, 5, 4, 5421)
# ('BMW', '3 Series', 2008, 2.5, 'Petrol', 'Automatic', 269266, 5, 3, 5114)
# ('Toyota', 'Camry', 2017, 5.0, 'Electric', 'Manual', 150119, 4, 1, 13197)
# ('BMW', '3 Series', 2002, 4.5, 'Petrol', 'Automatic', 45173, 4, 1, 9796)
# ('Volkswagen', 'Passat', 2010, 3.4, 'Petrol', 'Manual', 21440, 2, 1, 10071)
# ('Volkswagen', 'Golf', 2004, 3.7, 'Diesel', 'Manual', 141069, 2, 2, 6178)
# ('Audi', 'A4', 2005, 1.5, 'Hybrid', 'Semi-Automatic', 34067, 4, 4, 7418)
# ('Chevrolet', 'Impala', 2005, 3.4, 'Electric', 'Manual', 60019, 3, 1, 9799)
# ('BMW', '5 Series', 2001, 4.7, 'Petrol', 'Manual', 57858, 3, 5, 7942)
# ('Toyota', 'RAV4', 2013, 3.8, 'Petrol', 'Automatic', 46818, 4, 1, 12363)
# ('Audi', 'A4', 2013, 4.7, 'Electric', 'Automatic', 288444, 5, 4, 10431)
# ('BMW', '3 Series', 2008, 2.0, 'Petrol', 'Manual', 52053, 3, 2, 7458)
# ('BMW', '5 Series', 2009, 4.7, 'Hybrid', 'Semi-Automatic', 210522, 3, 2, 8289)
# ('Ford', 'Explorer', 2002, 4.8, 'Petrol', 'Semi-Automatic', 175627, 5, 3, 5987)
# ('Volkswagen', 'Tiguan', 2023, 1.5, 'Petrol', 'Semi-Automatic', 66909, 5, 3, 11161)
# ('Chevrolet', 'Equinox', 2016, 2.0, 'Hybrid', 'Manual', 86011, 4, 5, 10179)
# ('Ford', 'Fiesta', 2003, 1.2, 'Electric', 'Semi-Automatic', 83684, 3, 1, 6526)
# ('Kia', 'Rio', 2004, 1.0, 'Hybrid', 'Semi-Automatic', 204307, 3, 3, 3213)
# ('Volkswagen', 'Tiguan', 2019, 4.0, 'Hybrid', 'Automatic', 126676, 3, 3, 13766)
# ('Mercedes', 'E-Class', 2003, 4.7, 'Petrol', 'Automatic', 122256, 4, 5, 8754)
# ('Kia', 'Optima', 2023, 4.2, 'Petrol', 'Semi-Automatic', 173079, 3, 2, 11738)
# ('Ford', 'Fiesta', 2009, 3.1, 'Electric', 'Semi-Automatic', 1195, 3, 3, 11876)
# ('Audi', 'A4', 2013, 1.5, 'Diesel', 'Semi-Automatic', 137775, 2, 2, 6744)
# ('BMW', '5 Series', 2011, 1.2, 'Diesel', 'Automatic', 246312, 4, 5, 5173)
# ('Honda', 'CR-V', 2009, 2.8, 'Hybrid', 'Automatic', 13827, 4, 3, 11823)
# ('Honda', 'Civic', 2000, 1.9, 'Electric', 'Manual', 271834, 3, 1, 2563)
# ('BMW', '3 Series', 2004, 1.7, 'Diesel', 'Automatic', 241868, 5, 2, 3662)
# ('Mercedes', 'C-Class', 2013, 4.7, 'Petrol', 'Automatic', 28265, 3, 1, 13634)
# ('Ford', 'Fiesta', 2007, 4.5, 'Petrol', 'Automatic', 153372, 3, 2, 9132)
# ('Chevrolet', 'Equinox', 2005, 2.7, 'Hybrid', 'Manual', 271053, 2, 3, 3878)
# ('Audi', 'A4', 2018, 1.8, 'Electric', 'Semi-Automatic', 18543, 5, 3, 12929)
# ('Toyota', 'Camry', 2008, 4.0, 'Hybrid', 'Automatic', 19895, 2, 2, 12602)
# ('Ford', 'Focus', 2015, 5.0, 'Hybrid', 'Automatic', 17834, 3, 4, 15743)
# ('Chevrolet', 'Malibu', 2004, 4.2, 'Diesel', 'Semi-Automatic', 115683, 4, 4, 7186)
# ('Chevrolet', 'Malibu', 2015, 1.5, 'Electric', 'Semi-Automatic', 3559, 5, 3, 12028)
# ('Kia', 'Rio', 2019, 4.5, 'Hybrid', 'Automatic', 9917, 2, 3, 16601)
# ('Audi', 'Q5', 2011, 4.9, 'Electric', 'Semi-Automatic', 205843, 4, 4, 10183)
# ('Kia', 'Rio', 2002, 2.9, 'Electric', 'Automatic', 164637, 5, 2, 7807)
# ('Hyundai', 'Elantra', 2019, 3.3, 'Petrol', 'Manual', 223395, 5, 2, 8632)
# ('Toyota', 'Camry', 2023, 1.8, 'Petrol', 'Automatic', 60299, 4, 5, 13094)
# ('Audi', 'A3', 2007, 3.6, 'Diesel', 'Automatic', 19512, 4, 3, 10909)
# ('Chevrolet', 'Impala', 2019, 3.6, 'Petrol', 'Automatic', 224833, 4, 3, 10403)
# ('Chevrolet', 'Malibu', 2009, 4.5, 'Diesel', 'Automatic', 114528, 3, 3, 10509)
# ('Toyota', 'Camry', 2008, 2.1, 'Diesel', 'Automatic', 20894, 2, 5, 9682)
# ('Audi', 'Q5', 2023, 3.6, 'Diesel', 'Automatic', 226551, 3, 4, 11568)
# ('Volkswagen', 'Golf', 2002, 4.0, 'Hybrid', 'Automatic', 28845, 4, 5, 10623)
# ('Volkswagen', 'Golf', 2007, 2.5, 'Petrol', 'Manual', 165000, 3, 3, 5400)
# ('Honda', 'Accord', 2021, 4.0, 'Electric', 'Manual', 294376, 4, 3, 10512)
# ('Chevrolet', 'Impala', 2009, 2.7, 'Petrol', 'Semi-Automatic', 284027, 2, 5, 3819)
# ('Honda', 'Accord', 2005, 4.4, 'Petrol', 'Manual', 107963, 4, 4, 7840)
# ('Ford', 'Focus', 2016, 4.7, 'Electric', 'Semi-Automatic', 291218, 3, 2, 9775)
# ('Toyota', 'Camry', 2021, 1.3, 'Diesel', 'Semi-Automatic', 12904, 4, 3, 11441)
# ('Hyundai', 'Tucson', 2017, 2.8, 'Hybrid', 'Semi-Automatic', 191935, 4, 2, 9161)
# ('Ford', 'Explorer', 2003, 2.4, 'Petrol', 'Manual', 150463, 4, 3, 4390)
# ('BMW', '5 Series', 2021, 3.7, 'Diesel', 'Automatic', 298263, 3, 1, 9634)
# ('Honda', 'Accord', 2023, 1.7, 'Hybrid', 'Automatic', 274093, 5, 5, 9718)
# ('Volkswagen', 'Passat', 2009, 1.6, 'Petrol', 'Semi-Automatic', 81521, 2, 2, 6769)
# ('Volkswagen', 'Golf', 2007, 1.6, 'Electric', 'Manual', 12420, 3, 1, 9551)
# ('Ford', 'Fiesta', 2014, 4.4, 'Petrol', 'Manual', 271899, 2, 4, 7262)
# ('Toyota', 'RAV4', 2003, 2.6, 'Hybrid', 'Semi-Automatic', 179172, 3, 4, 5016)
# ('Mercedes', 'E-Class', 2014, 1.8, 'Electric', 'Automatic', 150548, 3, 2, 10589)
# ('Honda', 'Accord', 2021, 4.4, 'Diesel', 'Automatic', 292643, 5, 4, 10447)
# ('Mercedes', 'C-Class', 2019, 4.0, 'Diesel', 'Semi-Automatic', 40078, 3, 5, 12998)
# ('Hyundai', 'Tucson', 2007, 4.9, 'Electric', 'Automatic', 7559, 3, 5, 14448)
# ('Honda', 'CR-V', 2021, 4.4, 'Diesel', 'Manual', 60321, 2, 2, 13593)
# ('Hyundai', 'Tucson', 2012, 3.0, 'Diesel', 'Manual', 194978, 5, 1, 6800)
# ('Audi', 'Q5', 2008, 1.7, 'Hybrid', 'Manual', 297600, 4, 5, 3248)
# ('Kia', 'Optima', 2009, 1.7, 'Hybrid', 'Manual', 181774, 3, 3, 5864)
# ('Audi', 'Q5', 2018, 4.0, 'Electric', 'Automatic', 249695, 3, 4, 12006)
# ('Honda', 'Accord', 2000, 3.1, 'Hybrid', 'Manual', 65872, 5, 3, 6882)
# ('Honda', 'Civic', 2018, 2.0, 'Diesel', 'Manual', 194438, 2, 4, 7611)
# ('Honda', 'CR-V', 2019, 1.5, 'Hybrid', 'Automatic', 251069, 4, 3, 8778)
# ('Chevrolet', 'Impala', 2005, 2.0, 'Electric', 'Semi-Automatic', 213686, 3, 5, 5326)
# ('Honda', 'Accord', 2017, 2.6, 'Diesel', 'Manual', 248401, 5, 5, 6831)
# ('BMW', 'X5', 2020, 1.6, 'Electric', 'Manual', 111811, 4, 5, 11463)
# ('Audi', 'A3', 2023, 1.1, 'Hybrid', 'Semi-Automatic', 184, 2, 4, 13096)
# ('Hyundai', 'Elantra', 2021, 3.1, 'Diesel', 'Manual', 89567, 5, 5, 11708)
# ('Chevrolet', 'Impala', 2006, 3.7, 'Electric', 'Manual', 44684, 2, 2, 10706)
# ('Audi', 'Q5', 2014, 3.3, 'Hybrid', 'Automatic', 97781, 4, 3, 12144)
# ('Toyota', 'Corolla', 2009, 3.1, 'Electric', 'Automatic', 202524, 2, 5, 9349)
# ('Kia', 'Optima', 2004, 3.2, 'Electric', 'Manual', 165135, 3, 3, 7197)
# ('Hyundai', 'Sonata', 2003, 1.3, 'Petrol', 'Manual', 20083, 5, 4, 5898)
# ('Mercedes', 'C-Class', 2015, 1.3, 'Petrol', 'Automatic', 12241, 4, 5, 11155)
# ('Honda', 'Civic', 2004, 2.6, 'Electric', 'Semi-Automatic', 275293, 2, 4, 4394)
# ('Honda', 'CR-V', 2005, 3.4, 'Diesel', 'Semi-Automatic', 28746, 4, 5, 8425)
# ('Kia', 'Rio', 2017, 4.0, 'Electric', 'Automatic', 163393, 5, 4, 13432)
# ('Kia', 'Sportage', 2019, 4.0, 'Hybrid', 'Automatic', 77676, 4, 4, 14746)
# ('Mercedes', 'E-Class', 2003, 3.7, 'Petrol', 'Manual', 119469, 3, 2, 6310)
# ('Volkswagen', 'Golf', 2009, 2.2, 'Electric', 'Automatic', 134232, 4, 5, 9815)
# ('Chevrolet', 'Impala', 2023, 4.7, 'Petrol', 'Manual', 64538, 4, 2, 14409)
# ('Kia', 'Rio', 2021, 3.7, 'Electric', 'Automatic', 110781, 3, 4, 15384)
# ('Audi', 'A4', 2006, 1.1, 'Diesel', 'Automatic', 118381, 3, 3, 6132)
# ('Mercedes', 'GLA', 2005, 4.8, 'Hybrid', 'Semi-Automatic', 168485, 2, 5, 8030)
# ('Toyota', 'Corolla', 2010, 1.6, 'Petrol', 'Semi-Automatic', 76554, 2, 3, 7168)
# ('Toyota', 'RAV4', 2014, 4.9, 'Hybrid', 'Automatic', 45435, 3, 1, 14791)
# ('Hyundai', 'Elantra', 2005, 2.8, 'Diesel', 'Manual', 260651, 5, 5, 3186)
# ('Volkswagen', 'Passat', 2016, 4.9, 'Hybrid', 'Manual', 54089, 2, 5, 13718)
# ('Toyota', 'RAV4', 2001, 3.4, 'Hybrid', 'Manual', 38559, 5, 2, 8028)
# ('Volkswagen', 'Tiguan', 2015, 5.0, 'Diesel', 'Semi-Automatic', 69099, 5, 3, 12218)
# ('Hyundai', 'Sonata', 2015, 2.2, 'Petrol', 'Manual', 147721, 5, 1, 7845)
# ('Ford', 'Explorer', 2008, 1.6, 'Hybrid', 'Semi-Automatic', 209359, 4, 5, 4912)
# ('Ford', 'Fiesta', 2005, 3.4, 'Hybrid', 'Semi-Automatic', 176203, 2, 5, 6475)
# ('Mercedes', 'E-Class', 2008, 4.3, 'Hybrid', 'Automatic', 47221, 4, 2, 12355)
# ('Chevrolet', 'Impala', 2003, 2.9, 'Petrol', 'Semi-Automatic', 254487, 3, 3, 2810)
# ('Hyundai', 'Tucson', 2021, 4.6, 'Hybrid', 'Automatic', 43494, 5, 1, 16630)
# ('Toyota', 'Camry', 2007, 3.2, 'Hybrid', 'Manual', 220661, 4, 3, 5986)
# ('Kia', 'Rio', 2011, 2.5, 'Diesel', 'Manual', 106854, 4, 2, 7762)
# ('Hyundai', 'Sonata', 2018, 2.1, 'Hybrid', 'Automatic', 42010, 5, 3, 13259)
# ('BMW', 'X5', 2003, 5.0, 'Hybrid', 'Automatic', 186907, 2, 4, 8761)
# ('Chevrolet', 'Equinox', 2006, 1.5, 'Petrol', 'Semi-Automatic', 263388, 4, 3, 2132)
# ('Honda', 'Accord', 2017, 3.9, 'Electric', 'Semi-Automatic', 159408, 5, 5, 11911)
# ('Ford', 'Focus', 2018, 4.5, 'Hybrid', 'Manual', 214466, 3, 3, 10710)
# ('Toyota', 'RAV4', 2020, 2.7, 'Hybrid', 'Semi-Automatic', 229293, 4, 2, 9214)
# ('Mercedes', 'E-Class', 2013, 3.0, 'Electric', 'Semi-Automatic', 152475, 5, 1, 9950)
# ('Honda', 'Civic', 2019, 4.5, 'Electric', 'Semi-Automatic', 187412, 4, 1, 12551)
# ('Volkswagen', 'Passat', 2000, 2.7, 'Diesel', 'Manual', 163675, 2, 4, 3526)
# ('Mercedes', 'C-Class', 2018, 1.7, 'Electric', 'Semi-Automatic', 128889, 4, 2, 10622)
# ('Audi', 'A4', 2011, 2.2, 'Diesel', 'Automatic', 100297, 4, 1, 9094)
# ('Hyundai', 'Elantra', 2014, 4.5, 'Petrol', 'Manual', 84216, 3, 2, 11115)
# ('Toyota', 'Camry', 2012, 4.3, 'Electric', 'Semi-Automatic', 76558, 4, 5, 12468)
# ('BMW', 'X5', 2002, 2.7, 'Diesel', 'Automatic', 3714, 2, 4, 8825)
# ('Mercedes', 'E-Class', 2002, 4.5, 'Diesel', 'Semi-Automatic', 145363, 5, 2, 6292)
# ('Honda', 'CR-V', 2012, 1.5, 'Petrol', 'Manual', 37233, 3, 2, 8455)
# ('Ford', 'Fiesta', 2000, 1.5, 'Hybrid', 'Semi-Automatic', 140947, 2, 1, 3781)
# ('BMW', '5 Series', 2004, 1.3, 'Diesel', 'Manual', 19392, 2, 2, 6212)
# ('Toyota', 'Corolla', 2003, 1.6, 'Diesel', 'Semi-Automatic', 205647, 4, 4, 2487)
# ('Mercedes', 'E-Class', 2017, 1.1, 'Diesel', 'Automatic', 179286, 5, 1, 8214)
# ('BMW', '5 Series', 2016, 1.2, 'Hybrid', 'Automatic', 13386, 3, 5, 12332)
# ('Honda', 'Accord', 2019, 4.7, 'Hybrid', 'Semi-Automatic', 155874, 4, 3, 12382)
# ('Honda', 'Civic', 2016, 2.9, 'Petrol', 'Manual', 255889, 2, 2, 6682)
# ('BMW', '3 Series', 2010, 3.0, 'Petrol', 'Automatic', 86664, 5, 1, 9866)
# ('Ford', 'Explorer', 2002, 1.4, 'Hybrid', 'Automatic', 225772, 4, 1, 4084)
# ('Hyundai', 'Sonata', 2018, 1.5, 'Hybrid', 'Semi-Automatic', 181778, 5, 1, 8364)
# ('Chevrolet', 'Impala', 2002, 2.6, 'Electric', 'Manual', 67087, 3, 1, 7958)
# ('Honda', 'CR-V', 2008, 3.9, 'Diesel', 'Automatic', 221697, 4, 1, 7466)
# ('Volkswagen', 'Passat', 2023, 4.1, 'Hybrid', 'Manual', 68834, 3, 4, 14723)
# ('Toyota', 'Corolla', 2022, 3.6, 'Electric', 'Automatic', 4015, 2, 3, 17719)
# ('Volkswagen', 'Golf', 2003, 1.0, 'Hybrid', 'Automatic', 92129, 4, 3, 6657)
# ('Audi', 'A4', 2021, 4.1, 'Hybrid', 'Semi-Automatic', 192824, 4, 5, 11643)
# ('Honda', 'Civic', 2020, 1.7, 'Electric', 'Automatic', 126331, 3, 4, 12773)
# ('Audi', 'Q5', 2016, 3.9, 'Hybrid', 'Semi-Automatic', 188198, 4, 2, 10036)
# ('BMW', 'X5', 2001, 1.7, 'Electric', 'Automatic', 167431, 4, 3, 6251)
# ('Toyota', 'RAV4', 2019, 3.2, 'Petrol', 'Automatic', 95362, 5, 1, 12592)
# ('Mercedes', 'E-Class', 2019, 2.0, 'Diesel', 'Manual', 95927, 2, 5, 9881)
# ('Audi', 'A3', 2023, 1.2, 'Hybrid', 'Semi-Automatic', 247175, 4, 1, 8256)
# ('Chevrolet', 'Malibu', 2015, 2.5, 'Diesel', 'Automatic', 228993, 2, 3, 8020)
# ('BMW', '5 Series', 2015, 4.9, 'Diesel', 'Manual', 28128, 2, 4, 12937)
# ('Chevrolet', 'Impala', 2002, 4.2, 'Electric', 'Semi-Automatic', 213561, 5, 1, 6628)
# ('Kia', 'Sportage', 2018, 4.7, 'Diesel', 'Automatic', 265068, 3, 3, 10398)
# ('Audi', 'Q5', 2000, 3.2, 'Hybrid', 'Manual', 5681, 5, 2, 8186)
# ('Chevrolet', 'Malibu', 2023, 2.3, 'Petrol', 'Automatic', 233943, 2, 5, 10121)
# ('Chevrolet', 'Impala', 2011, 3.8, 'Electric', 'Semi-Automatic', 56331, 2, 5, 12073)
# ('Mercedes', 'E-Class', 2007, 2.3, 'Electric', 'Manual', 186395, 2, 5, 6772)
# ('Toyota', 'Camry', 2006, 2.5, 'Diesel', 'Semi-Automatic', 247781, 5, 4, 3444)
# ('Audi', 'A4', 2002, 1.9, 'Hybrid', 'Automatic', 40115, 2, 3, 8297)
# ('Kia', 'Sportage', 2004, 3.3, 'Hybrid', 'Semi-Automatic', 285789, 5, 2, 3884)
# ('Toyota', 'Camry', 2007, 1.4, 'Diesel', 'Manual', 248915, 4, 5, 2621)
# ('Hyundai', 'Elantra', 2000, 1.5, 'Petrol', 'Automatic', 17989, 3, 4, 6740)
# ('Kia', 'Optima', 2014, 4.6, 'Diesel', 'Semi-Automatic', 193673, 2, 4, 9026)
# ('Chevrolet', 'Equinox', 2020, 4.2, 'Electric', 'Semi-Automatic', 38561, 4, 2, 15528)
# ('Honda', 'CR-V', 2014, 2.2, 'Petrol', 'Semi-Automatic', 77361, 3, 2, 8952)
# ('Ford', 'Explorer', 2003, 3.0, 'Hybrid', 'Manual', 129742, 2, 3, 6405)
# ('Hyundai', 'Sonata', 2002, 2.6, 'Hybrid', 'Automatic', 247733, 3, 2, 4845)
# ('Hyundai', 'Elantra', 2016, 3.0, 'Electric', 'Manual', 200182, 3, 5, 9896)
# ('Audi', 'Q5', 2012, 3.8, 'Diesel', 'Semi-Automatic', 97556, 3, 3, 9548)
# ('Kia', 'Optima', 2002, 1.4, 'Hybrid', 'Automatic', 160394, 3, 2, 5392)
# ('Volkswagen', 'Passat', 2010, 4.3, 'Electric', 'Automatic', 36065, 5, 2, 14178)
# ('Kia', 'Rio', 2000, 3.4, 'Hybrid', 'Manual', 173249, 5, 2, 5035)
# ('Toyota', 'Camry', 2019, 4.5, 'Diesel', 'Manual', 74091, 5, 5, 12818)
# ('Honda', 'Accord', 2010, 4.3, 'Diesel', 'Semi-Automatic', 209937, 2, 5, 7201)
# ('Hyundai', 'Elantra', 2016, 2.2, 'Hybrid', 'Manual', 174820, 3, 4, 8603)
# ('Audi', 'Q5', 2013, 3.1, 'Electric', 'Manual', 46931, 4, 3, 12161)
# ('Audi', 'A4', 2001, 1.9, 'Hybrid', 'Automatic', 51262, 5, 3, 7774)
# ('Volkswagen', 'Golf', 2017, 4.9, 'Petrol', 'Automatic', 160438, 2, 5, 12391)
# ('BMW', '3 Series', 2011, 2.8, 'Diesel', 'Manual', 158111, 4, 5, 7037)
# ('Mercedes', 'C-Class', 2016, 3.4, 'Diesel', 'Automatic', 141737, 4, 1, 10965)
# ('Audi', 'A4', 2020, 3.9, 'Petrol', 'Manual', 91415, 5, 3, 12171)
# ('Kia', 'Optima', 2014, 4.3, 'Hybrid', 'Manual', 9628, 3, 1, 13407)
# ('Mercedes', 'GLA', 2011, 1.3, 'Petrol', 'Automatic', 26406, 2, 3, 9671)
# ('Audi', 'A3', 2006, 2.5, 'Petrol', 'Semi-Automatic', 155630, 2, 2, 5287)
# ('Chevrolet', 'Equinox', 2016, 3.9, 'Electric', 'Automatic', 99870, 5, 5, 14302)
# ('BMW', '3 Series', 2010, 2.0, 'Petrol', 'Manual', 259291, 4, 2, 3914)
# ('Volkswagen', 'Tiguan', 2021, 3.7, 'Petrol', 'Semi-Automatic', 156437, 2, 3, 10971)
# ('BMW', 'X5', 2002, 4.0, 'Hybrid', 'Semi-Automatic', 286275, 2, 4, 3974)
# ('Kia', 'Rio', 2003, 4.3, 'Petrol', 'Semi-Automatic', 274994, 4, 1, 3800)
# ('Mercedes', 'E-Class', 2022, 3.2, 'Petrol', 'Automatic', 92823, 5, 4, 13543)
# ('Audi', 'A4', 2003, 1.4, 'Hybrid', 'Automatic', 173657, 4, 3, 5426)
# ('Audi', 'A3', 2019, 1.8, 'Electric', 'Manual', 85496, 4, 3, 11890)
# ('Kia', 'Optima', 2004, 3.7, 'Diesel', 'Semi-Automatic', 5794, 2, 4, 8884)
# ('Chevrolet', 'Impala', 2002, 1.4, 'Electric', 'Automatic', 168000, 2, 1, 6240)
# ('Volkswagen', 'Tiguan', 2001, 2.1, 'Diesel', 'Manual', 157882, 3, 3, 3342)

# %%
'''
4) Напишите несколько SQL-запросов для извлечения данных из таблиц базы данных. Используйте условия фильтрации (например, WHERE) для получения нужных данных.
'''
# Out:
# '\n4) Напишите несколько SQL-запросов для извлечения данных из таблиц базы данных. Используйте условия фильтрации (например, WHERE) для получения нужных данных.\n'

# %%
import psycopg2
import logging

logging.basicConfig(filename='log.log', level=logging.INFO, format="%(asctime)s %(levelname)s %(module)s %(message)s") 
logger = logging.getLogger(__name__)

try:
    conn = psycopg2.connect(dbname="car_price_db", host="192.168.1.196", user="dwhadmin", password="123", port="5432")
except Exception as e:
    logger.exception(f"Ошибка подключения к БД: {e}")

cursor = conn.cursor()
print('Подключение выполнено')
cursor.execute("SELECT * FROM carprice where brand ='Audi' limit 5")
carprice_analyst = cursor.fetchall()
print('---=Audi---')
for carprice in carprice_analyst:
    print(carprice)
cursor.execute("SELECT * FROM carprice where price > 10000 limit 5")
carprice_analyst = cursor.fetchall()
print('---price >---')
for carprice in carprice_analyst:
    print(carprice)
cursor.execute("SELECT * FROM carprice where price between 15000 and 17000 limit 5")
carprice_analyst = cursor.fetchall()
print('---price between---')
for carprice in carprice_analyst:
    print(carprice)    
conn.close()
# Out:
# Подключение выполнено
# ---=Audi---
# ('Audi', 'Q5', 2023, 2.0, 'Electric', 'Manual', 160971, 2, 1, 11780)
# ('Audi', 'A3', 2022, 3.3, 'Electric', 'Manual', 79350, 5, 3, 14413)
# ('Audi', 'Q5', 2023, 3.6, 'Electric', 'Manual', 238306, 5, 2, 11833)
# ('Audi', 'A4', 2009, 2.4, 'Diesel', 'Manual', 263797, 2, 5, 3924)
# ('Audi', 'A3', 2009, 1.2, 'Electric', 'Automatic', 111448, 5, 1, 9271)
# ---price >---
# ('Audi', 'Q5', 2023, 2.0, 'Electric', 'Manual', 160971, 2, 1, 11780)
# ('Volkswagen', 'Golf', 2009, 4.5, 'Hybrid', 'Manual', 42795, 4, 3, 11444)
# ('Hyundai', 'Elantra', 2017, 2.9, 'Electric', 'Automatic', 38133, 5, 2, 14837)
# ('Mercedes', 'GLA', 2021, 1.5, 'Petrol', 'Manual', 34640, 2, 1, 11207)
# ('Chevrolet', 'Equinox', 2018, 1.8, 'Hybrid', 'Automatic', 21261, 2, 1, 13374)
# ---price between---
# ('Toyota', 'Corolla', 2022, 4.6, 'Diesel', 'Automatic', 48034, 3, 1, 15839)
# ('Toyota', 'Corolla', 2023, 3.4, 'Hybrid', 'Semi-Automatic', 19096, 3, 2, 15018)
# ('Kia', 'Optima', 2023, 3.6, 'Diesel', 'Automatic', 50457, 2, 4, 15090)
# ('Mercedes', 'C-Class', 2023, 2.9, 'Electric', 'Automatic', 102120, 4, 1, 15357)
# ('Volkswagen', 'Tiguan', 2020, 4.1, 'Electric', 'Automatic', 68269, 2, 3, 16334)

# %%
'''
5) Напишите SQL-запросы, использующие агрегатные функции (SUM, AVG, COUNT) для выполнения расчетов по данным таблицы.
'''
# Out:
# '\n5) Напишите SQL-запросы, использующие агрегатные функции (SUM, AVG, COUNT) для выполнения расчетов по данным таблицы.\n'

# %%
import psycopg2
import logging

logging.basicConfig(filename='log.log', level=logging.INFO, format="%(asctime)s %(levelname)s %(module)s %(message)s") 
logger = logging.getLogger(__name__)

try:
    conn = psycopg2.connect(dbname="car_price_db", host="192.168.1.196", user="dwhadmin", password="123", port="5432")
except Exception as e:
    logger.exception(f"Ошибка подключения к БД: {e}")

cursor = conn.cursor()
print('Подключение выполнено')
cursor.execute("SELECT count(*) FROM carprice where brand ='Audi'")
carprice_analyst = cursor.fetchall()
print('---count---')
print(carprice_analyst)

cursor.execute("SELECT sum(price) FROM carprice where brand in ('BMW','Audi','Volkswagen')")
carprice_analyst = cursor.fetchall()
print('---sum---')
print(carprice_analyst)

cursor.execute("SELECT ROUND(AVG(\"Year\")) FROM carprice where brand in ('Toyota','Honda')")
carprice_analyst = cursor.fetchall()
print('---AVG---')
for carprice in carprice_analyst:
    print(carprice)    
conn.close()
# Out:
# Подключение выполнено
# ---count---
# [(1038,)]
# ---sum---
# [(27070999,)]
# ---AVG---
# (Decimal('2011'),)

# %%
'''
6) Визуализируйте данные. Используйте библиотеки Python, такие как Matplotlib или Seaborn, для визуализации данных, извлеченных из базы данных. Постройте графики или диаграммы, которые помогут проанализировать и понять данные.
'''
# Out:
# '\n6) Визуализируйте данные. Используйте библиотеки Python, такие как Matplotlib или Seaborn, для визуализации данных, извлеченных из базы данных. Постройте графики или диаграммы, которые помогут проанализировать и понять данные.\n'

# %%
import psycopg2
import logging
import pandas as pd
import data_visualizer as dv

logging.basicConfig(filename='log.log', level=logging.INFO, format="%(asctime)s %(levelname)s %(module)s %(message)s") 
logger = logging.getLogger(__name__)

try:
    conn = psycopg2.connect(dbname="car_price_db", host="192.168.1.196", user="dwhadmin", password="123", port="5432")
except Exception as e:
    logger.exception(f"Ошибка подключения к БД: {e}")

try:

    cursor = conn.cursor()
    df = pd.read_sql_query("SELECT * FROM carprice where brand = 'Honda'", conn)
    visualizer = dv.DataVisualizer(df) 
    visualizer.add_histogram('price', 30, 0.9) 

    df = pd.read_sql_query("SELECT count(*) as cnt, \"Year\" FROM carprice group by \"Year\"", conn)
    visualizer = dv.DataVisualizer(df)    
    visualizer.add_line_plot('cnt', 'Year')

    df = pd.read_sql_query("SELECT * FROM carprice where brand = 'Chevrolet' ", conn)
    visualizer = dv.DataVisualizer(df)   
    visualizer.add_scatter_plot('Year', 'price')
     

finally:
    conn.close()
# Out:
# C:\Users\a.kozak\AppData\Local\Temp\ipykernel_10568\689578994.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM carprice where brand = 'Honda'", conn)
# C:\Users\a.kozak\AppData\Local\Temp\ipykernel_10568\689578994.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT count(*) as cnt, \"Year\" FROM carprice group by \"Year\"", conn)
# C:\Users\a.kozak\AppData\Local\Temp\ipykernel_10568\689578994.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM carprice where brand = 'Chevrolet' ", conn)
